# %%
import os
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
from matplotlib import pyplot as plt

import torch
import torch.nn as nn
from pytorch_tabnet.tab_model import TabNetClassifier

torch.manual_seed(0)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(0)

# %%
df = pd.read_parquet('./data/final_column제거.parquet')
train = df.copy()
# train = train.reset_index()

# %%
to_remove = train[train['PARTS_NO1'].isna()].index
train = train.drop(to_remove).reset_index()
to_remove = train.groupby('PARTS_NO1').filter(lambda x: len(x) <= 10000).index
train = train.drop(to_remove).reset_index()

# %%
# del train['KEY_PARTS1']
# del train['KEY_PARTS2']
# del train['KEY_PARTS3']
# del train['KEY_PARTS4']
# del train['KEY_PARTS5']
# # del train['PARTS_NO1']
del train['PARTS_NO2']
del train['PARTS_NO3']
del train['PARTS_NO4']
del train['PARTS_NO5']
del train['ENGINEER_REPAIR']
del train['level_0']
del train['index']
# del train['']

# %%
train = train.sample(frac=0.5).reset_index()
del train['index']

# %%
train.columns
# Out:
# Index(['MONTH', 'RECLAIM_PERIOD', 'SUBSIDIARY_NAME', 'CAPTIVE_CHANNEL_FLAG',
#        'COMPANY_CODE', 'DIVISION_NAME', 'MODEL_CODE', 'PARTS_NO1',
#        'RECEIPT_SYMPTOM', 'CENTER_CODE', 'PREV_CENTER_CODE', 'PRODUCT_NAME',
#        'RECLAIM', 'WARRANTY_TYPE', 'PREV_WARRANTY_TYPE', 'SVC_TYPE',
#        'PREV_SVC_TYPE', 'ENGINEER_CODE', 'PREV_ENGINEER_CODE',
#        'PREV_ENGINEER_SYMPTOM', 'MULTICLAIM', 'PREV_RECEIPT_SYMPTOM'],
#       dtype='object')

# %%
train.shape
# Out:
# (1501555, 22)

# %%
train['PARTS_NO1'].nunique()
# Out:
# 44

# %%
if "Set" not in train.columns:
    train["Set"] = np.random.choice(["train", "valid", "test"], p =[.7, .2, .1], size=(train.shape[0],))

train_indices = train[train["Set"]=="train"].index
valid_indices = train[train["Set"]=="valid"].index
test_indices = train[train["Set"]=="test"].index

# %%
train.columns[7]
# Out:
# 'PARTS_NO1'

# %%
train_indices
# Out:
# Index([      0,       1,       2,       3,       4,       6,       8,       9,
#             10,      13,
#        ...
#        1501544, 1501545, 1501546, 1501547, 1501548, 1501549, 1501550, 1501551,
#        1501552, 1501554],
#       dtype='int64', length=1050666)

# %%
target = train.columns[7]
nunique = train.nunique()
types = train.dtypes

categorical_columns = []
categorical_dims =  {}
for col in train.columns:
    print(types[col])
    if types[col] == 'object':
        train[col] = train[col].astype(str)
        print(col, train[col].nunique())
        train[col] = train[col].fillna("VV_likely")
        l_enc = LabelEncoder()
        # train[col] = train[col].fillna("VV_likely")
        train[col] = l_enc.fit_transform(train[col].values)
        categorical_columns.append(col)
        categorical_dims[col] = len(l_enc.classes_)
    else:
        train.fillna(train.loc[train_indices, col].mean(), inplace=True)


# Categorical Embedding을 위해 Categorical 변수의 차원과 idxs를 담음.
unused_feat = ['Set']
features = [ col for col in train.columns if col not in unused_feat+[target]] 
cat_idxs = [ i for i, f in enumerate(features) if f in categorical_columns]
cat_dims = [ categorical_dims[f] for i, f in enumerate(features) if f in categorical_columns]
# Out:
# object
# MONTH 12
# float64
# object
# SUBSIDIARY_NAME 2
# object
# CAPTIVE_CHANNEL_FLAG 2
# object
# COMPANY_CODE 3
# object
# DIVISION_NAME 17
# object
# MODEL_CODE 7588
# object
# PARTS_NO1 44
# object
# RECEIPT_SYMPTOM 153
# object
# CENTER_CODE 2069
# object
# PREV_CENTER_CODE 1450
# object
# PRODUCT_NAME 50
# int64
# object
# WARRANTY_TYPE 8
# object
# PREV_WARRANTY_TYPE 9
# object
# SVC_TYPE 8
# object
# PREV_SVC_TYPE 8
# object
# ENGINEER_CODE 20402
# object
# PREV_ENGINEER_CODE 11681
# object
# PREV_ENGINEER_SYMPTOM 116
# int64
# object
# PREV_RECEIPT_SYMPTOM 126
# object
# Set 3

# %%
X_train = train[features].values[train_indices]
y_train = train[target].values[train_indices]

X_valid = train[features].values[valid_indices]
y_valid = train[target].values[valid_indices]

X_test = train[features].values[test_indices]
y_test = train[target].values[test_indices]

# %%
clf = TabNetClassifier(n_d=16, n_a=16, n_steps=5, gamma=1.5,
                       n_independent=4, n_shared=4,
                       cat_idxs=cat_idxs,
                       cat_dims=cat_dims,
                       cat_emb_dim=10,
                       optimizer_fn=torch.optim.Adam,
                       optimizer_params=dict(lr=1e-2),
                       scheduler_params={"step_size":50,
                                         "gamma":0.9},
                       scheduler_fn=torch.optim.lr_scheduler.StepLR,
                       mask_type='sparsemax' # "sparsemax", entmax
                      )
# Out:
# /home/js/.conda/envs/LG/lib/python3.10/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cuda
#   warnings.warn(f"Device used : {self.device}")

# %%
# from pytorch_tabnet.augmentations import ClassificationSMOTE
max_epochs = 100
# aug = ClassificationSMOTE(p=0.2)

clf.fit(
    X_train=X_train, y_train=y_train,
    eval_set=[(X_train, y_train), (X_valid, y_valid)],
    eval_name=['train', 'valid'],
    max_epochs=max_epochs , patience=100,
    batch_size=128, virtual_batch_size=16,
    num_workers=0,
    weights=1,
    drop_last=False,
    # augmentations=aug
)
# Out:
# epoch 0  | loss: 1.93446 | train_accuracy: 0.76589 | valid_accuracy: 0.76463 |  0:01:30s
# epoch 1  | loss: 0.85755 | train_accuracy: 0.8342  | valid_accuracy: 0.82849 |  0:02:54s
# epoch 2  | loss: 0.7127  | train_accuracy: 0.85738 | valid_accuracy: 0.84818 |  0:04:08s
# epoch 3  | loss: 0.62537 | train_accuracy: 0.87472 | valid_accuracy: 0.86196 |  0:05:31s
# epoch 4  | loss: 0.56313 | train_accuracy: 0.87611 | valid_accuracy: 0.86156 |  0:06:53s
# epoch 5  | loss: 0.51438 | train_accuracy: 0.88934 | valid_accuracy: 0.87011 |  0:08:07s
# epoch 6  | loss: 0.48081 | train_accuracy: 0.89226 | valid_accuracy: 0.87082 |  0:09:28s
# epoch 7  | loss: 0.45652 | train_accuracy: 0.89934 | valid_accuracy: 0.87471 |  0:10:46s
# epoch 8  | loss: 0.43098 | train_accuracy: 0.90302 | valid_accuracy: 0.87588 |  0:12:11s
# epoch 9  | loss: 0.41075 | train_accuracy: 0.90608 | valid_accuracy: 0.87648 |  0:13:33s
# epoch 10 | loss: 0.39503 | train_accuracy: 0.90528 | valid_accuracy: 0.87406 |  0:15:00s
# epoch 11 | loss: 0.37606 | train_accuracy: 0.90969 | valid_accuracy: 0.87691 |  0:16:29s
# epoch 12 | loss: 0.36554 | train_accuracy: 0.91356 | valid_accuracy: 0.87845 |  0:18:00s
# epoch 13 | loss: 0.35264 | train_accuracy: 0.91195 | valid_accuracy: 0.8754  |  0:19:29s
# epoch 14 | loss: 0.33945 | train_accuracy: 0.90517 | valid_accuracy: 0.86729 |  0:20:59s
# epoch 15 | loss: 0.33194 | train_accuracy: 0.91534 | valid_accuracy: 0.87592 |  0:22:30s
# epoch 16 | loss: 0.31919 | train_accuracy: 0.88482 | valid_accuracy: 0.85596 |  0:24:00s
# epoch 17 | loss: 0.31105 | train_accuracy: 0.91794 | valid_accuracy: 0.87308 |  0:25:28s
# epoch 18 | loss: 0.30353 | train_accuracy: 0.92023 | valid_accuracy: 0.87664 |  0:26:56s
# epoch 19 | loss: 0.29756 | train_accuracy: 0.92301 | valid_accuracy: 0.87623 |  0:28:24s
# epoch 20 | loss: 0.29243 | train_accuracy: 0.90816 | valid_accuracy: 0.86737 |  0:29:50s
# epoch 21 | loss: 0.28585 | train_accuracy: 0.91057 | valid_accuracy: 0.8676  |  0:31:15s
# epoch 22 | loss: 0.28068 | train_accuracy: 0.92173 | valid_accuracy: 0.87245 |  0:32:42s
# epoch 23 | loss: 0.28434 | train_accuracy: 0.91645 | valid_accuracy: 0.87326 |  0:34:10s
# epoch 24 | loss: 0.27834 | train_accuracy: 0.91781 | valid_accuracy: 0.86842 |  0:35:37s
# epoch 25 | loss: 0.26839 | train_accuracy: 0.92657 | valid_accuracy: 0.87605 |  0:37:04s
# epoch 26 | loss: 0.26408 | train_accuracy: 0.91894 | valid_accuracy: 0.86702 |  0:38:32s
# epoch 27 | loss: 0.26599 | train_accuracy: 0.91414 | valid_accuracy: 0.86778 |  0:39:59s
# epoch 28 | loss: 0.26004 | train_accuracy: 0.92722 | valid_accuracy: 0.87398 |  0:41:27s
# epoch 29 | loss: 0.25737 | train_accuracy: 0.93187 | valid_accuracy: 0.87927 |  0:42:55s
# epoch 30 | loss: 0.25356 | train_accuracy: 0.92987 | valid_accuracy: 0.87406 |  0:44:21s
# epoch 31 | loss: 0.24694 | train_accuracy: 0.93194 | valid_accuracy: 0.87814 |  0:45:46s
# epoch 32 | loss: 0.24975 | train_accuracy: 0.93027 | valid_accuracy: 0.87597 |  0:47:14s
# epoch 33 | loss: 0.24376 | train_accuracy: 0.91699 | valid_accuracy: 0.87149 |  0:48:43s
# epoch 34 | loss: 0.24315 | train_accuracy: 0.919   | valid_accuracy: 0.86927 |  0:50:08s
# epoch 35 | loss: 0.24507 | train_accuracy: 0.93482 | valid_accuracy: 0.8795  |  0:51:37s
# epoch 36 | loss: 0.244   | train_accuracy: 0.93149 | valid_accuracy: 0.87523 |  0:53:05s
# epoch 37 | loss: 0.23673 | train_accuracy: 0.93095 | valid_accuracy: 0.87482 |  0:54:37s
# epoch 38 | loss: 0.24299 | train_accuracy: 0.92627 | valid_accuracy: 0.87429 |  0:56:07s
# epoch 39 | loss: 0.23394 | train_accuracy: 0.92241 | valid_accuracy: 0.86979 |  0:57:38s
# epoch 40 | loss: 0.23081 | train_accuracy: 0.93236 | valid_accuracy: 0.8742  |  0:59:07s
# epoch 41 | loss: 0.24233 | train_accuracy: 0.92327 | valid_accuracy: 0.87214 |  1:00:35s
# epoch 42 | loss: 0.23997 | train_accuracy: 0.92926 | valid_accuracy: 0.87215 |  1:02:03s
# epoch 43 | loss: 0.22201 | train_accuracy: 0.93002 | valid_accuracy: 0.87233 |  1:03:30s
# epoch 44 | loss: 0.22137 | train_accuracy: 0.93058 | valid_accuracy: 0.87431 |  1:04:59s
# epoch 45 | loss: 0.22213 | train_accuracy: 0.91789 | valid_accuracy: 0.86886 |  1:06:29s
# epoch 46 | loss: 0.22031 | train_accuracy: 0.93715 | valid_accuracy: 0.87733 |  1:07:57s
# epoch 47 | loss: 0.22018 | train_accuracy: 0.93606 | valid_accuracy: 0.87404 |  1:09:25s
# epoch 48 | loss: 0.21658 | train_accuracy: 0.93544 | valid_accuracy: 0.8751  |  1:10:52s
# epoch 49 | loss: 0.21681 | train_accuracy: 0.91734 | valid_accuracy: 0.87064 |  1:12:21s
# epoch 50 | loss: 0.21095 | train_accuracy: 0.923   | valid_accuracy: 0.87092 |  1:13:49s
# epoch 51 | loss: 0.20893 | train_accuracy: 0.94042 | valid_accuracy: 0.87631 |  1:15:19s
# epoch 52 | loss: 0.21064 | train_accuracy: 0.93726 | valid_accuracy: 0.87576 |  1:16:46s
# epoch 53 | loss: 0.2175  | train_accuracy: 0.93012 | valid_accuracy: 0.8706  |  1:18:17s
# epoch 54 | loss: 0.2043  | train_accuracy: 0.93882 | valid_accuracy: 0.87573 |  1:19:48s
# epoch 55 | loss: 0.20399 | train_accuracy: 0.9338  | valid_accuracy: 0.87273 |  1:21:18s
# epoch 56 | loss: 0.20106 | train_accuracy: 0.94054 | valid_accuracy: 0.87533 |  1:22:48s
# epoch 57 | loss: 0.20129 | train_accuracy: 0.93629 | valid_accuracy: 0.87196 |  1:24:21s
# epoch 58 | loss: 0.2006  | train_accuracy: 0.92914 | valid_accuracy: 0.87368 |  1:25:54s
# epoch 59 | loss: 0.19987 | train_accuracy: 0.93842 | valid_accuracy: 0.87406 |  1:27:25s
# epoch 60 | loss: 0.19729 | train_accuracy: 0.94058 | valid_accuracy: 0.87523 |  1:28:56s
# epoch 61 | loss: 0.20143 | train_accuracy: 0.93898 | valid_accuracy: 0.87284 |  1:30:25s
# epoch 62 | loss: 0.19456 | train_accuracy: 0.94202 | valid_accuracy: 0.87742 |  1:31:58s
# epoch 63 | loss: 0.19466 | train_accuracy: 0.9407  | valid_accuracy: 0.87601 |  1:33:31s
# epoch 64 | loss: 0.19643 | train_accuracy: 0.93704 | valid_accuracy: 0.87154 |  1:35:03s
# epoch 65 | loss: 0.19477 | train_accuracy: 0.94131 | valid_accuracy: 0.87618 |  1:36:35s
# epoch 66 | loss: 0.19422 | train_accuracy: 0.93036 | valid_accuracy: 0.87163 |  1:38:07s
# epoch 67 | loss: 0.19824 | train_accuracy: 0.9447  | valid_accuracy: 0.87792 |  1:39:38s
# epoch 68 | loss: 0.19299 | train_accuracy: 0.94017 | valid_accuracy: 0.87304 |  1:41:07s
# epoch 69 | loss: 0.19242 | train_accuracy: 0.94371 | valid_accuracy: 0.87679 |  1:42:35s
# epoch 70 | loss: 0.19596 | train_accuracy: 0.93431 | valid_accuracy: 0.87125 |  1:44:06s
# epoch 71 | loss: 0.19521 | train_accuracy: 0.93134 | valid_accuracy: 0.87417 |  1:45:38s
# epoch 72 | loss: 0.19345 | train_accuracy: 0.94053 | valid_accuracy: 0.87377 |  1:47:09s
# epoch 73 | loss: 0.18908 | train_accuracy: 0.94087 | valid_accuracy: 0.87396 |  1:48:38s
# epoch 74 | loss: 0.18808 | train_accuracy: 0.94562 | valid_accuracy: 0.87808 |  1:50:07s
# epoch 75 | loss: 0.19432 | train_accuracy: 0.94175 | valid_accuracy: 0.8759  |  1:51:34s
# epoch 76 | loss: 0.19125 | train_accuracy: 0.93379 | valid_accuracy: 0.87594 |  1:53:01s
# epoch 77 | loss: 0.1874  | train_accuracy: 0.94254 | valid_accuracy: 0.87592 |  1:54:27s
# epoch 78 | loss: 0.18836 | train_accuracy: 0.93928 | valid_accuracy: 0.87556 |  1:55:54s
# epoch 79 | loss: 0.18409 | train_accuracy: 0.94377 | valid_accuracy: 0.87568 |  1:57:21s
# epoch 80 | loss: 0.18403 | train_accuracy: 0.93816 | valid_accuracy: 0.87547 |  1:58:48s
# epoch 81 | loss: 0.18464 | train_accuracy: 0.9365  | valid_accuracy: 0.87444 |  2:00:15s
# epoch 82 | loss: 0.18522 | train_accuracy: 0.9326  | valid_accuracy: 0.87343 |  2:01:40s
# epoch 83 | loss: 0.18338 | train_accuracy: 0.9418  | valid_accuracy: 0.87498 |  2:03:09s
# epoch 84 | loss: 0.18181 | train_accuracy: 0.9436  | valid_accuracy: 0.87336 |  2:04:36s
# epoch 85 | loss: 0.18003 | train_accuracy: 0.94169 | valid_accuracy: 0.87482 |  2:06:03s
# epoch 86 | loss: 0.18427 | train_accuracy: 0.94377 | valid_accuracy: 0.87719 |  2:07:31s
# epoch 87 | loss: 0.18115 | train_accuracy: 0.94615 | valid_accuracy: 0.87813 |  2:08:58s
# epoch 88 | loss: 0.18066 | train_accuracy: 0.94189 | valid_accuracy: 0.87545 |  2:10:25s
# epoch 89 | loss: 0.17847 | train_accuracy: 0.94488 | valid_accuracy: 0.87661 |  2:11:53s
# epoch 90 | loss: 0.17994 | train_accuracy: 0.94549 | valid_accuracy: 0.87586 |  2:13:19s
# epoch 91 | loss: 0.17942 | train_accuracy: 0.94203 | valid_accuracy: 0.87706 |  2:14:46s
# epoch 92 | loss: 0.18045 | train_accuracy: 0.94143 | valid_accuracy: 0.8733  |  2:16:14s
# epoch 93 | loss: 0.17653 | train_accuracy: 0.93954 | valid_accuracy: 0.87492 |  2:17:41s
# epoch 94 | loss: 0.17573 | train_accuracy: 0.93506 | valid_accuracy: 0.87457 |  2:19:10s
# epoch 95 | loss: 0.17355 | train_accuracy: 0.94418 | valid_accuracy: 0.87398 |  2:20:39s
# epoch 96 | loss: 0.17461 | train_accuracy: 0.9448  | valid_accuracy: 0.87468 |  2:22:07s
# epoch 97 | loss: 0.17703 | train_accuracy: 0.94493 | valid_accuracy: 0.87575 |  2:23:35s
# epoch 98 | loss: 0.17953 | train_accuracy: 0.94462 | valid_accuracy: 0.87594 |  2:25:05s
# epoch 99 | loss: 0.17732 | train_accuracy: 0.94554 | valid_accuracy: 0.87545 |  2:26:35s
# epoch 100| loss: 0.17231 | train_accuracy: 0.94776 | valid_accuracy: 0.87688 |  2:28:04s
# epoch 101| loss: 0.16845 | train_accuracy: 0.94267 | valid_accuracy: 0.87544 |  2:29:27s
# epoch 102| loss: 0.16899 | train_accuracy: 0.94662 | valid_accuracy: 0.87502 |  2:30:56s
# epoch 103| loss: 0.16881 | train_accuracy: 0.94759 | valid_accuracy: 0.87857 |  2:32:26s
# epoch 104| loss: 0.17017 | train_accuracy: 0.94214 | valid_accuracy: 0.87617 |  2:33:52s
# epoch 105| loss: 0.17052 | train_accuracy: 0.94284 | valid_accuracy: 0.87265 |  2:35:20s
# epoch 106| loss: 0.16816 | train_accuracy: 0.94296 | valid_accuracy: 0.87119 |  2:36:50s
# epoch 107| loss: 0.1672  | train_accuracy: 0.9498  | valid_accuracy: 0.87893 |  2:38:21s
# epoch 108| loss: 0.16697 | train_accuracy: 0.94704 | valid_accuracy: 0.87548 |  2:39:50s
# epoch 109| loss: 0.17434 | train_accuracy: 0.94819 | valid_accuracy: 0.87627 |  2:41:24s
# epoch 110| loss: 0.16736 | train_accuracy: 0.94853 | valid_accuracy: 0.87733 |  2:42:55s
# epoch 111| loss: 0.16685 | train_accuracy: 0.94764 | valid_accuracy: 0.87535 |  2:44:28s
# epoch 112| loss: 0.16564 | train_accuracy: 0.94249 | valid_accuracy: 0.87512 |  2:45:59s
# epoch 113| loss: 0.16794 | train_accuracy: 0.95126 | valid_accuracy: 0.87954 |  2:47:29s
# epoch 114| loss: 0.16629 | train_accuracy: 0.94857 | valid_accuracy: 0.87808 |  2:48:57s
# epoch 115| loss: 0.16664 | train_accuracy: 0.94368 | valid_accuracy: 0.87524 |  2:50:26s
# epoch 116| loss: 0.1691  | train_accuracy: 0.94695 | valid_accuracy: 0.87688 |  2:51:54s
# epoch 117| loss: 0.17038 | train_accuracy: 0.94165 | valid_accuracy: 0.87016 |  2:53:20s
# epoch 118| loss: 0.16403 | train_accuracy: 0.931   | valid_accuracy: 0.86836 |  2:54:51s
# epoch 119| loss: 0.16293 | train_accuracy: 0.94525 | valid_accuracy: 0.87374 |  2:56:23s
# epoch 120| loss: 0.16351 | train_accuracy: 0.94671 | valid_accuracy: 0.87751 |  2:57:53s
# epoch 121| loss: 0.16869 | train_accuracy: 0.94747 | valid_accuracy: 0.87737 |  2:59:24s
# epoch 122| loss: 0.16522 | train_accuracy: 0.942   | valid_accuracy: 0.87376 |  3:00:56s
# epoch 123| loss: 0.16436 | train_accuracy: 0.94599 | valid_accuracy: 0.87621 |  3:02:30s
# epoch 124| loss: 0.16275 | train_accuracy: 0.93308 | valid_accuracy: 0.87354 |  3:04:03s
# epoch 125| loss: 0.16064 | train_accuracy: 0.94369 | valid_accuracy: 0.8752  |  3:05:33s
# epoch 126| loss: 0.16019 | train_accuracy: 0.94855 | valid_accuracy: 0.87752 |  3:07:04s
# epoch 127| loss: 0.16132 | train_accuracy: 0.95055 | valid_accuracy: 0.87725 |  3:08:36s
# epoch 128| loss: 0.16108 | train_accuracy: 0.94475 | valid_accuracy: 0.87302 |  3:10:09s
# epoch 129| loss: 0.16281 | train_accuracy: 0.9471  | valid_accuracy: 0.87453 |  3:11:42s
# epoch 130| loss: 0.16154 | train_accuracy: 0.93632 | valid_accuracy: 0.87466 |  3:13:14s
# epoch 131| loss: 0.16058 | train_accuracy: 0.94533 | valid_accuracy: 0.87568 |  3:14:45s
# epoch 132| loss: 0.16011 | train_accuracy: 0.94745 | valid_accuracy: 0.87674 |  3:16:16s
# epoch 133| loss: 0.16217 | train_accuracy: 0.92143 | valid_accuracy: 0.86857 |  3:17:47s
# epoch 134| loss: 0.1637  | train_accuracy: 0.94989 | valid_accuracy: 0.87761 |  3:19:18s
# epoch 135| loss: 0.16047 | train_accuracy: 0.93619 | valid_accuracy: 0.87358 |  3:20:52s
# epoch 136| loss: 0.15738 | train_accuracy: 0.95088 | valid_accuracy: 0.87754 |  3:22:21s
# epoch 137| loss: 0.16047 | train_accuracy: 0.94092 | valid_accuracy: 0.87092 |  3:23:51s
# epoch 138| loss: 0.15803 | train_accuracy: 0.94531 | valid_accuracy: 0.8725  |  3:25:21s
# epoch 139| loss: 0.16009 | train_accuracy: 0.94831 | valid_accuracy: 0.87679 |  3:26:51s
# epoch 140| loss: 0.15898 | train_accuracy: 0.94924 | valid_accuracy: 0.87498 |  3:28:18s
# epoch 141| loss: 0.1591  | train_accuracy: 0.93794 | valid_accuracy: 0.87438 |  3:29:45s
# epoch 142| loss: 0.15645 | train_accuracy: 0.94966 | valid_accuracy: 0.87455 |  3:31:14s
# epoch 143| loss: 0.15847 | train_accuracy: 0.92732 | valid_accuracy: 0.86867 |  3:32:43s
# epoch 144| loss: 0.15877 | train_accuracy: 0.95106 | valid_accuracy: 0.87714 |  3:34:13s
# epoch 145| loss: 0.15939 | train_accuracy: 0.93872 | valid_accuracy: 0.86967 |  3:35:42s
# epoch 146| loss: 0.15843 | train_accuracy: 0.94685 | valid_accuracy: 0.87629 |  3:37:12s
# epoch 147| loss: 0.15653 | train_accuracy: 0.95043 | valid_accuracy: 0.87771 |  3:38:39s
# epoch 148| loss: 0.15725 | train_accuracy: 0.94954 | valid_accuracy: 0.87727 |  3:40:08s
# epoch 149| loss: 0.15549 | train_accuracy: 0.95267 | valid_accuracy: 0.87883 |  3:41:40s
# epoch 150| loss: 0.15385 | train_accuracy: 0.95363 | valid_accuracy: 0.87993 |  3:43:11s
# epoch 151| loss: 0.15167 | train_accuracy: 0.9528  | valid_accuracy: 0.87937 |  3:44:42s
# epoch 152| loss: 0.15388 | train_accuracy: 0.93245 | valid_accuracy: 0.87029 |  3:46:13s
# epoch 153| loss: 0.15564 | train_accuracy: 0.95163 | valid_accuracy: 0.87788 |  3:47:41s
# epoch 154| loss: 0.15485 | train_accuracy: 0.95099 | valid_accuracy: 0.87611 |  3:49:14s
# epoch 155| loss: 0.15298 | train_accuracy: 0.92784 | valid_accuracy: 0.86846 |  3:50:42s
# epoch 156| loss: 0.15303 | train_accuracy: 0.941   | valid_accuracy: 0.87379 |  3:52:10s
# epoch 157| loss: 0.1523  | train_accuracy: 0.93914 | valid_accuracy: 0.87354 |  3:53:38s
# epoch 158| loss: 0.15454 | train_accuracy: 0.9477  | valid_accuracy: 0.87425 |  3:55:09s
# epoch 159| loss: 0.15439 | train_accuracy: 0.94971 | valid_accuracy: 0.87599 |  3:56:40s
# epoch 160| loss: 0.15344 | train_accuracy: 0.95084 | valid_accuracy: 0.87585 |  3:58:10s
# epoch 161| loss: 0.1531  | train_accuracy: 0.95313 | valid_accuracy: 0.8776  |  3:59:37s
# epoch 162| loss: 0.15321 | train_accuracy: 0.95345 | valid_accuracy: 0.87811 |  4:01:06s
# epoch 163| loss: 0.15142 | train_accuracy: 0.94612 | valid_accuracy: 0.87199 |  4:02:36s
# epoch 164| loss: 0.15487 | train_accuracy: 0.93829 | valid_accuracy: 0.87416 |  4:04:06s
# epoch 165| loss: 0.1494  | train_accuracy: 0.94786 | valid_accuracy: 0.87387 |  4:05:35s
# epoch 166| loss: 0.15164 | train_accuracy: 0.94347 | valid_accuracy: 0.87479 |  4:07:01s
# epoch 167| loss: 0.15355 | train_accuracy: 0.94305 | valid_accuracy: 0.87546 |  4:08:26s
# epoch 168| loss: 0.14931 | train_accuracy: 0.95077 | valid_accuracy: 0.87538 |  4:09:50s
# epoch 169| loss: 0.14958 | train_accuracy: 0.94015 | valid_accuracy: 0.87207 |  4:11:17s
# epoch 170| loss: 0.14929 | train_accuracy: 0.95216 | valid_accuracy: 0.87696 |  4:12:40s
# epoch 171| loss: 0.15753 | train_accuracy: 0.9426  | valid_accuracy: 0.87164 |  4:14:09s
# epoch 172| loss: 0.15098 | train_accuracy: 0.94946 | valid_accuracy: 0.87594 |  4:15:37s
# epoch 173| loss: 0.15065 | train_accuracy: 0.95001 | valid_accuracy: 0.87547 |  4:17:05s
# epoch 174| loss: 0.1528  | train_accuracy: 0.92933 | valid_accuracy: 0.8671  |  4:18:33s
# epoch 175| loss: 0.15065 | train_accuracy: 0.94534 | valid_accuracy: 0.87216 |  4:20:00s
# epoch 176| loss: 0.14831 | train_accuracy: 0.92983 | valid_accuracy: 0.87011 |  4:21:17s
# epoch 177| loss: 0.15049 | train_accuracy: 0.93043 | valid_accuracy: 0.86929 |  4:22:44s
# epoch 178| loss: 0.14867 | train_accuracy: 0.94484 | valid_accuracy: 0.87507 |  4:24:09s
# epoch 179| loss: 0.15045 | train_accuracy: 0.9532  | valid_accuracy: 0.87637 |  4:25:35s
# epoch 180| loss: 0.14811 | train_accuracy: 0.94138 | valid_accuracy: 0.87506 |  4:27:03s
# epoch 181| loss: 0.15224 | train_accuracy: 0.9474  | valid_accuracy: 0.87473 |  4:28:32s
# epoch 182| loss: 0.15311 | train_accuracy: 0.95082 | valid_accuracy: 0.87749 |  4:30:00s
# epoch 183| loss: 0.15326 | train_accuracy: 0.95073 | valid_accuracy: 0.8782  |  4:31:29s
# epoch 184| loss: 0.14976 | train_accuracy: 0.95109 | valid_accuracy: 0.87672 |  4:32:52s
# epoch 185| loss: 0.14961 | train_accuracy: 0.91555 | valid_accuracy: 0.86149 |  4:34:16s
# epoch 186| loss: 0.15068 | train_accuracy: 0.95157 | valid_accuracy: 0.87658 |  4:35:44s
# epoch 187| loss: 0.15331 | train_accuracy: 0.95279 | valid_accuracy: 0.8764  |  4:37:08s
# epoch 188| loss: 0.15243 | train_accuracy: 0.94965 | valid_accuracy: 0.87686 |  4:38:34s
# epoch 189| loss: 0.14806 | train_accuracy: 0.94946 | valid_accuracy: 0.87564 |  4:40:01s
# epoch 190| loss: 0.14653 | train_accuracy: 0.95374 | valid_accuracy: 0.8783  |  4:41:26s
# epoch 191| loss: 0.14809 | train_accuracy: 0.95158 | valid_accuracy: 0.87635 |  4:42:53s
# epoch 192| loss: 0.14776 | train_accuracy: 0.944   | valid_accuracy: 0.87512 |  4:44:18s
# epoch 193| loss: 0.14936 | train_accuracy: 0.95037 | valid_accuracy: 0.87778 |  4:45:45s
# epoch 194| loss: 0.14862 | train_accuracy: 0.95254 | valid_accuracy: 0.87536 |  4:47:13s
# epoch 195| loss: 0.14737 | train_accuracy: 0.9541  | valid_accuracy: 0.87804 |  4:48:39s
# epoch 196| loss: 0.14957 | train_accuracy: 0.95487 | valid_accuracy: 0.87851 |  4:50:05s
# epoch 197| loss: 0.15014 | train_accuracy: 0.94312 | valid_accuracy: 0.87604 |  4:51:35s
# epoch 198| loss: 0.1507  | train_accuracy: 0.9532  | valid_accuracy: 0.87692 |  4:53:04s
# epoch 199| loss: 0.149   | train_accuracy: 0.94499 | valid_accuracy: 0.87302 |  4:54:31s
# epoch 200| loss: 0.14533 | train_accuracy: 0.95382 | valid_accuracy: 0.87821 |  4:55:53s
# epoch 201| loss: 0.14387 | train_accuracy: 0.9509  | valid_accuracy: 0.87599 |  4:57:19s
# epoch 202| loss: 0.14358 | train_accuracy: 0.95463 | valid_accuracy: 0.87728 |  4:58:44s
# epoch 203| loss: 0.1422  | train_accuracy: 0.95004 | valid_accuracy: 0.87684 |  5:00:08s
# epoch 204| loss: 0.14299 | train_accuracy: 0.95503 | valid_accuracy: 0.87821 |  5:01:29s
# epoch 205| loss: 0.14471 | train_accuracy: 0.95042 | valid_accuracy: 0.87609 |  5:02:56s
# epoch 206| loss: 0.14125 | train_accuracy: 0.95237 | valid_accuracy: 0.87612 |  5:04:21s
# epoch 207| loss: 0.14273 | train_accuracy: 0.94621 | valid_accuracy: 0.87769 |  5:05:46s
# epoch 208| loss: 0.14306 | train_accuracy: 0.95017 | valid_accuracy: 0.87722 |  5:07:13s
# epoch 209| loss: 0.14352 | train_accuracy: 0.95386 | valid_accuracy: 0.87692 |  5:08:40s
# epoch 210| loss: 0.14469 | train_accuracy: 0.94645 | valid_accuracy: 0.87545 |  5:10:08s
# epoch 211| loss: 0.14289 | train_accuracy: 0.93903 | valid_accuracy: 0.87165 |  5:11:31s
# epoch 212| loss: 0.14537 | train_accuracy: 0.94967 | valid_accuracy: 0.87523 |  5:12:58s
# epoch 213| loss: 0.14242 | train_accuracy: 0.9433  | valid_accuracy: 0.87484 |  5:14:23s
# epoch 214| loss: 0.14141 | train_accuracy: 0.94433 | valid_accuracy: 0.87477 |  5:15:48s
# epoch 215| loss: 0.14124 | train_accuracy: 0.93798 | valid_accuracy: 0.87414 |  5:17:14s
# epoch 216| loss: 0.14114 | train_accuracy: 0.95389 | valid_accuracy: 0.87704 |  5:18:40s
# epoch 217| loss: 0.14271 | train_accuracy: 0.94494 | valid_accuracy: 0.87453 |  5:20:07s
# epoch 218| loss: 0.1411  | train_accuracy: 0.9544  | valid_accuracy: 0.87716 |  5:21:33s
# epoch 219| loss: 0.1413  | train_accuracy: 0.95017 | valid_accuracy: 0.87543 |  5:22:58s
# epoch 220| loss: 0.14311 | train_accuracy: 0.95453 | valid_accuracy: 0.87688 |  5:24:24s
# epoch 221| loss: 0.14311 | train_accuracy: 0.95467 | valid_accuracy: 0.87722 |  5:25:49s
# epoch 222| loss: 0.14356 | train_accuracy: 0.95525 | valid_accuracy: 0.87808 |  5:27:19s
# epoch 223| loss: 0.14019 | train_accuracy: 0.94052 | valid_accuracy: 0.87307 |  5:28:47s
# epoch 224| loss: 0.14075 | train_accuracy: 0.94515 | valid_accuracy: 0.8748  |  5:30:11s
# epoch 225| loss: 0.13981 | train_accuracy: 0.95332 | valid_accuracy: 0.87573 |  5:31:36s
# epoch 226| loss: 0.14102 | train_accuracy: 0.95268 | valid_accuracy: 0.87752 |  5:33:01s
# epoch 227| loss: 0.13912 | train_accuracy: 0.95437 | valid_accuracy: 0.8761  |  5:34:28s
# epoch 228| loss: 0.13855 | train_accuracy: 0.95581 | valid_accuracy: 0.87719 |  5:35:54s
# epoch 229| loss: 0.1395  | train_accuracy: 0.94635 | valid_accuracy: 0.8725  |  5:37:20s
# epoch 230| loss: 0.14036 | train_accuracy: 0.95378 | valid_accuracy: 0.87482 |  5:38:46s
# epoch 231| loss: 0.14055 | train_accuracy: 0.95484 | valid_accuracy: 0.87662 |  5:40:09s
# epoch 232| loss: 0.1403  | train_accuracy: 0.95343 | valid_accuracy: 0.87546 |  5:41:36s
# epoch 233| loss: 0.14085 | train_accuracy: 0.95475 | valid_accuracy: 0.87603 |  5:43:00s
# epoch 234| loss: 0.14245 | train_accuracy: 0.95682 | valid_accuracy: 0.87868 |  5:44:25s
# epoch 235| loss: 0.1401  | train_accuracy: 0.95628 | valid_accuracy: 0.87734 |  5:45:50s
# epoch 236| loss: 0.14062 | train_accuracy: 0.95493 | valid_accuracy: 0.87725 |  5:47:15s
# epoch 237| loss: 0.13996 | train_accuracy: 0.957   | valid_accuracy: 0.87812 |  5:48:42s
# epoch 238| loss: 0.13953 | train_accuracy: 0.95275 | valid_accuracy: 0.87764 |  5:50:07s
# epoch 239| loss: 0.13777 | train_accuracy: 0.95722 | valid_accuracy: 0.87907 |  5:51:35s
# epoch 240| loss: 0.14141 | train_accuracy: 0.95419 | valid_accuracy: 0.87648 |  5:53:03s
# epoch 241| loss: 0.13988 | train_accuracy: 0.94808 | valid_accuracy: 0.87501 |  5:54:32s
# epoch 242| loss: 0.13745 | train_accuracy: 0.95241 | valid_accuracy: 0.8766  |  5:56:02s
# epoch 243| loss: 0.1395  | train_accuracy: 0.95074 | valid_accuracy: 0.8761  |  5:57:29s
# epoch 244| loss: 0.14089 | train_accuracy: 0.95371 | valid_accuracy: 0.87533 |  5:58:54s
# epoch 245| loss: 0.14295 | train_accuracy: 0.95472 | valid_accuracy: 0.87679 |  6:00:20s
# epoch 246| loss: 0.1399  | train_accuracy: 0.95458 | valid_accuracy: 0.87798 |  6:01:47s
# epoch 247| loss: 0.13873 | train_accuracy: 0.956   | valid_accuracy: 0.87891 |  6:03:13s
# epoch 248| loss: 0.13973 | train_accuracy: 0.95572 | valid_accuracy: 0.87648 |  6:04:38s
# epoch 249| loss: 0.14035 | train_accuracy: 0.95533 | valid_accuracy: 0.87794 |  6:06:05s
# epoch 250| loss: 0.1384  | train_accuracy: 0.95492 | valid_accuracy: 0.87894 |  6:07:30s
#
# Early stopping occurred at epoch 250 with best_epoch = 150 and best_valid_accuracy = 0.87993
# /home/js/.conda/envs/LG/lib/python3.10/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)

# %%
from sklearn.metrics import accuracy_score

preds_mapper = { idx : class_name for idx, class_name in enumerate(clf.classes_)}

preds = clf.predict_proba(X_test)

y_pred = np.vectorize(preds_mapper.get)(np.argmax(preds, axis=1))

test_acc = accuracy_score(y_pred=y_pred, y_true=y_test)

print(f"BEST VALID SCORE : {clf.best_cost}")
print(f"FINAL TEST SCORE : {test_acc}")
# Out:
# BEST VALID SCORE : 0.8799270972858066
# FINAL TEST SCORE : 0.8786903948581548

# %%
from sklearn.metrics import f1_score

# Macro F1 score
f1_macro = f1_score(y_test, y_pred, average='macro')
print("Macro F1 Score:", f1_macro)
# Out:
# Macro F1 Score: 0.7098230087204951

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# 혼동 행렬 계산
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(40, 32))

# 혼동 행렬 시각화
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
explain_matrix, masks = clf.explain(X_test)
indices = [i for i, x in enumerate(y_pred) if x == 6]
fig, axs = plt.subplots(1, 3, figsize=(10,40))
for i in range(3):
    # random_indices = np.random.choice(masks[i].shape[0], 500, replace=False)
    axs[i].imshow(masks[i][indices[:50]])
    axs[i].set_title(f"mask {i}")

# %%
train.columns[5]
# Out:
# 'DIVISION_NAME'

# %%
# global
feat_importances = pd.Series(clf.feature_importances_, index=features)
feat_importances.plot(kind='barh', figsize=(10,10))
# Out:
# <Axes: >
