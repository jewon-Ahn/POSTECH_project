# %%
from pathlib import Path

import matplotlib.pyplot as pl
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split

import shap
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
data = pd.read_parquet('../postech_company_project_2.parquet')

# take all data where "TO_RECLAIM" is 1
# and take the same number of data where "TO_RECLAIM" is 0 sampled randomly
# this is to avoid overfitting
to_reclaim_count = data[data['TO_RECLAIM'] == 1].shape[0]
not_to_reclaim_count = data[data['TO_RECLAIM'] == 0].shape[0]

sample_count = min(to_reclaim_count, not_to_reclaim_count)
data = pd.concat([data[data['TO_RECLAIM'] == 0].sample(n=sample_count),
                  data[data['TO_RECLAIM'] == 1].sample(n=sample_count)])

# check if the data is balanced
data['TO_RECLAIM'].value_counts()
# Out:
# TO_RECLAIM
# 0    358704
# 1    358704
# Name: count, dtype: int64

# %%
remove_cols = ['MULTICLAIM', 'RECLAIM_PERIOD', 'PARTS_DESC1', 'PARTS_DESC2', 'PARTS_DESC3', 'PARTS_DESC4', 'PARTS_DESC5', 'PREV_PARTS_DESC1', 'PREV_PARTS_DESC2', 'PREV_PARTS_DESC3', 'PREV_PARTS_DESC4', 'PREV_PARTS_DESC5', 'TO_RECLAIM_NUMBER', 'YEAR_YYYY', 'MONTH_YYYYMM', 'PREV_RECEIPT_NUMBER', 'RECEIPT_NUMBER', 'ENGINEER_CODE', 'ENGINEER_SYMPTOM', 'ENGINEER_REPAIR', 'PARTS_NO1', 'PARTS_NO2', 'PARTS_NO3', 'PARTS_NO4', 'PARTS_NO5', 'KEY_PARTS1', 'KEY_PARTS2', 'KEY_PARTS3', 'KEY_PARTS4', 'KEY_PARTS5', 'KEY_PARTS_REMARK1', 'KEY_PARTS_REMARK2', 'KEY_PARTS_REMARK3', 'KEY_PARTS_REMARK4', 'KEY_PARTS_REMARK5']
target = 'TO_RECLAIM'

# drop data in remove_cols
data1 = data.drop(columns=remove_cols)

display(data1.head())

categorical_columns = [col for col in data1.columns if col != target and data1[col].dtype == 'object']
mapping = {}
for col in categorical_columns:
    data1[col], mapping[col] = pd.factorize(data1[col], use_na_sentinel=True)

# Replace NaNs with -1
data1.fillna(-1, inplace=True)

display(data1.head())

features = [col for col in data1.columns if col != target]
X_train, X_valid, y_train, y_valid = train_test_split(data1[features], data1[target], test_size=0.2, random_state=0)
dt = xgb.DMatrix(X_train, label=y_train)
dv = xgb.DMatrix(X_valid, label=y_valid)
# Out:
#                    WEEK_YYYYWWW SUBSIDIARY_NAME CAPTIVE_CHANNEL_FLAG  \
# RECEIPT_NUMBER_IDX
# 4598466                 2022W30           LGEIL          Non Captive
# 3950389                 2022W25           LGEIL              Captive
# 13859654                2023W25           LGEIL              Captive
# 13550359                2023W23           LGEIL              Captive
# 5265227                 2022W26           LGEIL              Captive
#
#                    COMPANY_CODE DIVISION_NAME   MODEL_CODE PREV_PARTS_NO1  \
# RECEIPT_NUMBER_IDX
# 4598466                      HA           W/M   FHT1207ZNL           None
# 3950389                      HA           W/M     P8035R3S           None
# 13859654                     HE           LTV  65UN7300PTC           None
# 13550359                     HA           W/M    T75SKSF1Z           None
# 5265227                      HA           W/M    T75CME21P           None
#
#                    PREV_PARTS_NO2 PREV_PARTS_NO3 PREV_PARTS_NO4  ...  \
# RECEIPT_NUMBER_IDX                                               ...
# 4598466                      None           None           None  ...
# 3950389                      None           None           None  ...
# 13859654                     None           None           None  ...
# 13550359                     None           None           None  ...
# 5265227                      None           None           None  ...
#
#                    PREV_KEY_PARTS4 PREV_KEY_PARTS5  PREV_KEY_PARTS_REMARK1  \
# RECEIPT_NUMBER_IDX
# 4598466                        0.0             0.0                    None
# 3950389                        0.0             0.0                    None
# 13859654                       0.0             0.0                    None
# 13550359                       0.0             0.0                    None
# 5265227                        0.0             0.0                    None
#
#                     PREV_KEY_PARTS_REMARK2 PREV_KEY_PARTS_REMARK3  \
# RECEIPT_NUMBER_IDX
# 4598466                               None                   None
# 3950389                               None                   None
# 13859654                              None                   None
# 13550359                              None                   None
# 5265227                               None                   None
#
#                    PREV_KEY_PARTS_REMARK4 PREV_KEY_PARTS_REMARK5  \
# RECEIPT_NUMBER_IDX
# 4598466                              None                   None
# 3950389                              None                   None
# 13859654                             None                   None
# 13550359                             None                   None
# 5265227                              None                   None
#
#                    PREV_RECEIPT_SYMPTOM  PREV_RECEIPT_NUMBER_IDX TO_RECLAIM
# RECEIPT_NUMBER_IDX
# 4598466                            None                     None          0
# 3950389                            None                     None          0
# 13859654                           None                     None          0
# 13550359                           None                     None          0
# 5265227                            None                     None          0
#
# [5 rows x 39 columns]
#                     WEEK_YYYYWWW  SUBSIDIARY_NAME  CAPTIVE_CHANNEL_FLAG  \
# RECEIPT_NUMBER_IDX
# 4598466                        0                0                     0
# 3950389                        1                0                     1
# 13859654                       2                0                     1
# 13550359                       3                0                     1
# 5265227                        4                0                     1
#
#                     COMPANY_CODE  DIVISION_NAME  MODEL_CODE  PREV_PARTS_NO1  \
# RECEIPT_NUMBER_IDX
# 4598466                        0              0           0              -1
# 3950389                        0              0           1              -1
# 13859654                       1              1           2              -1
# 13550359                       0              0           3              -1
# 5265227                        0              0           4              -1
#
#                     PREV_PARTS_NO2  PREV_PARTS_NO3  PREV_PARTS_NO4  ...  \
# RECEIPT_NUMBER_IDX                                                  ...
# 4598466                         -1              -1              -1  ...
# 3950389                         -1              -1              -1  ...
# 13859654                        -1              -1              -1  ...
# 13550359                        -1              -1              -1  ...
# 5265227                         -1              -1              -1  ...
#
#                     PREV_KEY_PARTS4  PREV_KEY_PARTS5  PREV_KEY_PARTS_REMARK1  \
# RECEIPT_NUMBER_IDX
# 4598466                         0.0              0.0                      -1
# 3950389                         0.0              0.0                      -1
# 13859654                        0.0              0.0                      -1
# 13550359                        0.0              0.0                      -1
# 5265227                         0.0              0.0                      -1
#
#                     PREV_KEY_PARTS_REMARK2  PREV_KEY_PARTS_REMARK3  \
# RECEIPT_NUMBER_IDX
# 4598466                                 -1                      -1
# 3950389                                 -1                      -1
# 13859654                                -1                      -1
# 13550359                                -1                      -1
# 5265227                                 -1                      -1
#
#                     PREV_KEY_PARTS_REMARK4  PREV_KEY_PARTS_REMARK5  \
# RECEIPT_NUMBER_IDX
# 4598466                                 -1                      -1
# 3950389                                 -1                      -1
# 13859654                                -1                      -1
# 13550359                                -1                      -1
# 5265227                                 -1                      -1
#
#                     PREV_RECEIPT_SYMPTOM  PREV_RECEIPT_NUMBER_IDX  TO_RECLAIM
# RECEIPT_NUMBER_IDX
# 4598466                               -1                       -1           0
# 3950389                               -1                       -1           0
# 13859654                              -1                       -1           0
# 13550359                              -1                       -1           0
# 5265227                               -1                       -1           0
#
# [5 rows x 39 columns]

# %%
params = {
    "objective": "binary:logistic",
    "base_score": np.mean(y_train),
    "eval_metric": "logloss",
}

xgb_model = xgb.train(
    params,
    dt,
    num_boost_round=10,
    evals=[(dt, "train"), (dv, "valid")],
    early_stopping_rounds=5,
    verbose_eval=25,
)
# Out:
# [0]	train-logloss:0.63343	valid-logloss:0.63304
# [9]	train-logloss:0.54658	valid-logloss:0.54527

# %%
# get the predicted values for the validation set
y_pred = xgb_model.predict(dv)

# convert the predicted values to binary (0 or 1) based on a threshold of 0.5
y_pred_binary = [1 if x >= 0.5 else 0 for x in y_pred]

# calculate the accuracy of the model
accuracy = sum(y_pred_binary == y_valid) / len(y_valid)
print("Accuracy:", accuracy)

# show me the correctnees by 2x2 table
from sklearn.metrics import confusion_matrix
confusion_matrix(y_valid, y_pred_binary)
# Out:
# Accuracy: 0.7097336251237089
# array([[47026, 24629],
#        [17019, 54808]])

# %%
shap.initjs()
xbg_explainer = shap.TreeExplainer(xgb_model)
xbg_shap_values = xbg_explainer.shap_values(X_valid)

shap.summary_plot(xbg_shap_values, X_valid)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# [16:09:22] WARNING: /workspace/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
shap.force_plot(xbg_explainer.expected_value, xbg_shap_values[0, :], X_valid.iloc[0, :])
# Out:
# <div id='iOXYAI8PUPRVDMTDVGPU0'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.0026336251758038998, "outValue": 0.10592461377382278, "link": "identity", "featureNames": ["WEEK_YYYYWWW", "SUBSIDIARY_NAME", "CAPTIVE_CHANNEL_FLAG", "COMPANY_CODE", "DIVISION_NAME", "MODEL_CODE", "PREV_PARTS_NO1", "PREV_PARTS_NO2", "PREV_PARTS_NO3", "PREV_PARTS_NO4", "PREV_PARTS_NO5", "RECEIPT_SYMPTOM", "REPAIR_START_DATE", "REPAIR_END_DATE", "CENTER_CODE", "PREV_CENTER_CODE", "PRODUCT_NAME", "PRODUCT_NAME_DETAIL", "RECLAIM", "WARRANTY_TYPE", "PREV_WARRANTY_TYPE", "SVC_TYPE", "PREV_SVC_TYPE", "PREV_ENGINEER_CODE", "PREV_ENGINEER_SYMPTOM", "PREV_ENGINEER_REPAIR", "PREV_KEY_PARTS1", "PREV_KEY_PARTS2", "PREV_KEY_PARTS3", "PREV_KEY_PARTS4", "PREV_KEY_PARTS5", "PREV_KEY_PARTS_REMARK1", "PREV_KEY_PARTS_REMARK2", "PREV_KEY_PARTS_REMARK3", "PREV_KEY_PARTS_REMARK4", "PREV_KEY_PARTS_REMARK5", "PREV_RECEIPT_SYMPTOM", "PREV_RECEIPT_NUMBER_IDX"], "features": {"0": {"effect": -0.0010336155537515879, "value": 36.0}, "1": {"effect": -0.11392712593078613, "value": 0.0}, "2": {"effect": -0.0034032296389341354, "value": 1.0}, "3": {"effect": 0.0021265163086354733, "value": 0.0}, "4": {"effect": -0.024852130562067032, "value": 0.0}, "5": {"effect": -0.0019595567137002945, "value": 305.0}, "6": {"effect": -3.5761513572651893e-06, "value": -1.0}, "7": {"effect": -1.441217591491295e-06, "value": -1.0}, "11": {"effect": 0.03093743696808815, "value": 3.0}, "12": {"effect": -0.07091031968593597, "value": 20230112.0}, "13": {"effect": 0.047482557594776154, "value": 20230112.0}, "14": {"effect": -0.001278589479625225, "value": 330.0}, "15": {"effect": 0.00022136964253149927, "value": -1.0}, "16": {"effect": -0.013416563160717487, "value": 0.0}, "17": {"effect": 0.06981488317251205, "value": 11.0}, "19": {"effect": -0.1438819319009781, "value": 0.0}, "20": {"effect": 0.0414004772901535, "value": 0.0}, "21": {"effect": 0.4189046025276184, "value": 2.0}, "22": {"effect": 4.236188487993786e-06, "value": 0.0}, "23": {"effect": -4.032087304040033e-07, "value": -1.0}, "24": {"effect": -2.921370651165489e-06, "value": 0.0}, "36": {"effect": -4.192698725091759e-06, "value": -1.0}, "37": {"effect": -0.13292548060417175, "value": -1.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iOXYAI8PUPRVDMTDVGPU0')
#   );
# </script>

# %%
import lightgbm as lgb

dt = lgb.Dataset(X_train, label=y_train)
dv = lgb.Dataset(X_valid, label=y_valid)

params = {
    "max_bin": 512,
    "learning_rate": 0.05,
    "boosting_type": "gbdt",
    "objective": "binary",
    "metric": "binary_logloss",
    "num_leaves": 10,
    "verbose": -1,
    "min_data": 100,
    "boost_from_average": True,
    "early_stopping_round": 50,
}

lgb_model = lgb.train(
    params,
    dt,
    10000,
    valid_sets=[dv],
)
# Out:
# [1]	valid_0's binary_logloss: 0.682182
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's binary_logloss: 0.672243
# [3]	valid_0's binary_logloss: 0.663233
# [4]	valid_0's binary_logloss: 0.655031
# [5]	valid_0's binary_logloss: 0.647563
# [6]	valid_0's binary_logloss: 0.640736
# [7]	valid_0's binary_logloss: 0.634494
# [8]	valid_0's binary_logloss: 0.628773
# [9]	valid_0's binary_logloss: 0.623534
# [10]	valid_0's binary_logloss: 0.618653
# [11]	valid_0's binary_logloss: 0.614176
# [12]	valid_0's binary_logloss: 0.609963
# [13]	valid_0's binary_logloss: 0.60612
# [14]	valid_0's binary_logloss: 0.60257
# [15]	valid_0's binary_logloss: 0.599252
# [16]	valid_0's binary_logloss: 0.596185
# [17]	valid_0's binary_logloss: 0.593403
# [18]	valid_0's binary_logloss: 0.590765
# [19]	valid_0's binary_logloss: 0.588326
# [20]	valid_0's binary_logloss: 0.58614
# [21]	valid_0's binary_logloss: 0.584003
# [22]	valid_0's binary_logloss: 0.581976
# [23]	valid_0's binary_logloss: 0.580067
# [24]	valid_0's binary_logloss: 0.578243
# [25]	valid_0's binary_logloss: 0.576488
# [26]	valid_0's binary_logloss: 0.574893
# [27]	valid_0's binary_logloss: 0.573392
# [28]	valid_0's binary_logloss: 0.571993
# [29]	valid_0's binary_logloss: 0.570683
# [30]	valid_0's binary_logloss: 0.569452
# [31]	valid_0's binary_logloss: 0.568362
# [32]	valid_0's binary_logloss: 0.567289
# [33]	valid_0's binary_logloss: 0.56628
# [34]	valid_0's binary_logloss: 0.565279
# [35]	valid_0's binary_logloss: 0.564354
# [36]	valid_0's binary_logloss: 0.563536
# [37]	valid_0's binary_logloss: 0.562732
# [38]	valid_0's binary_logloss: 0.561907
# [39]	valid_0's binary_logloss: 0.561101
# [40]	valid_0's binary_logloss: 0.560336
# [41]	valid_0's binary_logloss: 0.559589
# [42]	valid_0's binary_logloss: 0.558867
# [43]	valid_0's binary_logloss: 0.558199
# [44]	valid_0's binary_logloss: 0.557545
# [45]	valid_0's binary_logloss: 0.556876
# [46]	valid_0's binary_logloss: 0.556339
# [47]	valid_0's binary_logloss: 0.55574
# [48]	valid_0's binary_logloss: 0.555241
# [49]	valid_0's binary_logloss: 0.554781
# [50]	valid_0's binary_logloss: 0.554255
# [51]	valid_0's binary_logloss: 0.553796
# [52]	valid_0's binary_logloss: 0.553385
# [53]	valid_0's binary_logloss: 0.55289
# [54]	valid_0's binary_logloss: 0.552447
# [55]	valid_0's binary_logloss: 0.552069
# [56]	valid_0's binary_logloss: 0.551654
# [57]	valid_0's binary_logloss: 0.551322
# [58]	valid_0's binary_logloss: 0.550956
# [59]	valid_0's binary_logloss: 0.550656
# [60]	valid_0's binary_logloss: 0.550293
# [61]	valid_0's binary_logloss: 0.549997
# [62]	valid_0's binary_logloss: 0.549658
# [63]	valid_0's binary_logloss: 0.549301
# [64]	valid_0's binary_logloss: 0.549
# [65]	valid_0's binary_logloss: 0.548732
# [66]	valid_0's binary_logloss: 0.548462
# [67]	valid_0's binary_logloss: 0.548195
# [68]	valid_0's binary_logloss: 0.547938
# [69]	valid_0's binary_logloss: 0.547693
# [70]	valid_0's binary_logloss: 0.54747
# [71]	valid_0's binary_logloss: 0.547185
# [72]	valid_0's binary_logloss: 0.546982
# [73]	valid_0's binary_logloss: 0.546825
# [74]	valid_0's binary_logloss: 0.546655
# [75]	valid_0's binary_logloss: 0.546458
# [76]	valid_0's binary_logloss: 0.546231
# [77]	valid_0's binary_logloss: 0.546069
# [78]	valid_0's binary_logloss: 0.545896
# [79]	valid_0's binary_logloss: 0.54568
# [80]	valid_0's binary_logloss: 0.545451
# [81]	valid_0's binary_logloss: 0.545269
# [82]	valid_0's binary_logloss: 0.545119
# [83]	valid_0's binary_logloss: 0.544956
# [84]	valid_0's binary_logloss: 0.544823
# [85]	valid_0's binary_logloss: 0.544693
# [86]	valid_0's binary_logloss: 0.544572
# [87]	valid_0's binary_logloss: 0.544423
# [88]	valid_0's binary_logloss: 0.544297
# [89]	valid_0's binary_logloss: 0.544192
# [90]	valid_0's binary_logloss: 0.544056
# [91]	valid_0's binary_logloss: 0.543916
# [92]	valid_0's binary_logloss: 0.543748
# [93]	valid_0's binary_logloss: 0.543623
# [94]	valid_0's binary_logloss: 0.543515
# [95]	valid_0's binary_logloss: 0.543423
# [96]	valid_0's binary_logloss: 0.543271
# [97]	valid_0's binary_logloss: 0.543171
# [98]	valid_0's binary_logloss: 0.543071
# [99]	valid_0's binary_logloss: 0.54299
# [100]	valid_0's binary_logloss: 0.542882
# [101]	valid_0's binary_logloss: 0.542714
# [102]	valid_0's binary_logloss: 0.542632
# [103]	valid_0's binary_logloss: 0.542516
# [104]	valid_0's binary_logloss: 0.542442
# [105]	valid_0's binary_logloss: 0.542354
# [106]	valid_0's binary_logloss: 0.542275
# [107]	valid_0's binary_logloss: 0.542174
# [108]	valid_0's binary_logloss: 0.542107
# [109]	valid_0's binary_logloss: 0.542023
# [110]	valid_0's binary_logloss: 0.541919
# [111]	valid_0's binary_logloss: 0.541835
# [112]	valid_0's binary_logloss: 0.541758
# [113]	valid_0's binary_logloss: 0.541697
# [114]	valid_0's binary_logloss: 0.541613
# [115]	valid_0's binary_logloss: 0.541552
# [116]	valid_0's binary_logloss: 0.541482
# [117]	valid_0's binary_logloss: 0.541398
# [118]	valid_0's binary_logloss: 0.541311
# [119]	valid_0's binary_logloss: 0.541261
# [120]	valid_0's binary_logloss: 0.541136
# [121]	valid_0's binary_logloss: 0.541078
# [122]	valid_0's binary_logloss: 0.540955
# [123]	valid_0's binary_logloss: 0.540857
# [124]	valid_0's binary_logloss: 0.54079
# [125]	valid_0's binary_logloss: 0.54071
# [126]	valid_0's binary_logloss: 0.540643
# [127]	valid_0's binary_logloss: 0.540579
# [128]	valid_0's binary_logloss: 0.540494
# [129]	valid_0's binary_logloss: 0.540411
# [130]	valid_0's binary_logloss: 0.540375
# [131]	valid_0's binary_logloss: 0.540311
# [132]	valid_0's binary_logloss: 0.540253
# [133]	valid_0's binary_logloss: 0.540156
# [134]	valid_0's binary_logloss: 0.5401
# [135]	valid_0's binary_logloss: 0.540055
# [136]	valid_0's binary_logloss: 0.540013
# [137]	valid_0's binary_logloss: 0.53994
# [138]	valid_0's binary_logloss: 0.539896
# [139]	valid_0's binary_logloss: 0.539811
# [140]	valid_0's binary_logloss: 0.539756
# [141]	valid_0's binary_logloss: 0.539686
# [142]	valid_0's binary_logloss: 0.539646
# [143]	valid_0's binary_logloss: 0.539595
# [144]	valid_0's binary_logloss: 0.539532
# [145]	valid_0's binary_logloss: 0.539479
# [146]	valid_0's binary_logloss: 0.53944
# [147]	valid_0's binary_logloss: 0.539368
# [148]	valid_0's binary_logloss: 0.539315
# [149]	valid_0's binary_logloss: 0.53928
# [150]	valid_0's binary_logloss: 0.539206
# [151]	valid_0's binary_logloss: 0.539164
# [152]	valid_0's binary_logloss: 0.539119
# [153]	valid_0's binary_logloss: 0.539024
# [154]	valid_0's binary_logloss: 0.53897
# [155]	valid_0's binary_logloss: 0.538919
# [156]	valid_0's binary_logloss: 0.538823
# [157]	valid_0's binary_logloss: 0.538759
# [158]	valid_0's binary_logloss: 0.53871
# [159]	valid_0's binary_logloss: 0.538663
# [160]	valid_0's binary_logloss: 0.538624
# [161]	valid_0's binary_logloss: 0.538582
# [162]	valid_0's binary_logloss: 0.538536
# [163]	valid_0's binary_logloss: 0.538452
# [164]	valid_0's binary_logloss: 0.538423
# [165]	valid_0's binary_logloss: 0.538379
# [166]	valid_0's binary_logloss: 0.538343
# [167]	valid_0's binary_logloss: 0.538289
# [168]	valid_0's binary_logloss: 0.538259
# [169]	valid_0's binary_logloss: 0.538211
# [170]	valid_0's binary_logloss: 0.538173
# [171]	valid_0's binary_logloss: 0.538132
# [172]	valid_0's binary_logloss: 0.538095
# [173]	valid_0's binary_logloss: 0.538043
# [174]	valid_0's binary_logloss: 0.538002
# [175]	valid_0's binary_logloss: 0.537953
# [176]	valid_0's binary_logloss: 0.537906
# [177]	valid_0's binary_logloss: 0.537859
# [178]	valid_0's binary_logloss: 0.537818
# [179]	valid_0's binary_logloss: 0.537776
# [180]	valid_0's binary_logloss: 0.537732
# [181]	valid_0's binary_logloss: 0.537667
# [182]	valid_0's binary_logloss: 0.537591
# [183]	valid_0's binary_logloss: 0.537511
# [184]	valid_0's binary_logloss: 0.537476
# [185]	valid_0's binary_logloss: 0.537421
# [186]	valid_0's binary_logloss: 0.5374
# [187]	valid_0's binary_logloss: 0.537366
# [188]	valid_0's binary_logloss: 0.5373
# [189]	valid_0's binary_logloss: 0.537267
# [190]	valid_0's binary_logloss: 0.537242
# [191]	valid_0's binary_logloss: 0.537223
# [192]	valid_0's binary_logloss: 0.537162
# [193]	valid_0's binary_logloss: 0.537091
# [194]	valid_0's binary_logloss: 0.53706
# [195]	valid_0's binary_logloss: 0.537022
# [196]	valid_0's binary_logloss: 0.536983
# [197]	valid_0's binary_logloss: 0.536917
# [198]	valid_0's binary_logloss: 0.536885
# [199]	valid_0's binary_logloss: 0.536857
# [200]	valid_0's binary_logloss: 0.536831
# [201]	valid_0's binary_logloss: 0.536795
# [202]	valid_0's binary_logloss: 0.536749
# [203]	valid_0's binary_logloss: 0.536724
# [204]	valid_0's binary_logloss: 0.536697
# [205]	valid_0's binary_logloss: 0.536662
# [206]	valid_0's binary_logloss: 0.53664
# [207]	valid_0's binary_logloss: 0.536618
# [208]	valid_0's binary_logloss: 0.536585
# [209]	valid_0's binary_logloss: 0.536523
# [210]	valid_0's binary_logloss: 0.536497
# [211]	valid_0's binary_logloss: 0.536445
# [212]	valid_0's binary_logloss: 0.536406
# [213]	valid_0's binary_logloss: 0.536388
# [214]	valid_0's binary_logloss: 0.536354
# [215]	valid_0's binary_logloss: 0.536333
# [216]	valid_0's binary_logloss: 0.536274
# [217]	valid_0's binary_logloss: 0.536211
# [218]	valid_0's binary_logloss: 0.536176
# [219]	valid_0's binary_logloss: 0.53615
# [220]	valid_0's binary_logloss: 0.536121
# [221]	valid_0's binary_logloss: 0.536089
# [222]	valid_0's binary_logloss: 0.53605
# [223]	valid_0's binary_logloss: 0.536023
# [224]	valid_0's binary_logloss: 0.536001
# [225]	valid_0's binary_logloss: 0.535973
# [226]	valid_0's binary_logloss: 0.535951
# [227]	valid_0's binary_logloss: 0.535919
# [228]	valid_0's binary_logloss: 0.535891
# [229]	valid_0's binary_logloss: 0.535867
# [230]	valid_0's binary_logloss: 0.535826
# [231]	valid_0's binary_logloss: 0.535804
# [232]	valid_0's binary_logloss: 0.535779
# [233]	valid_0's binary_logloss: 0.535732
# [234]	valid_0's binary_logloss: 0.535712
# [235]	valid_0's binary_logloss: 0.53566
# [236]	valid_0's binary_logloss: 0.535634
# [237]	valid_0's binary_logloss: 0.535619
# [238]	valid_0's binary_logloss: 0.535602
# [239]	valid_0's binary_logloss: 0.535584
# [240]	valid_0's binary_logloss: 0.535567
# [241]	valid_0's binary_logloss: 0.535535
# [242]	valid_0's binary_logloss: 0.535517
# [243]	valid_0's binary_logloss: 0.535484
# [244]	valid_0's binary_logloss: 0.535466
# [245]	valid_0's binary_logloss: 0.535441
# [246]	valid_0's binary_logloss: 0.535395
# [247]	valid_0's binary_logloss: 0.535378
# [248]	valid_0's binary_logloss: 0.535336
# [249]	valid_0's binary_logloss: 0.53532
# [250]	valid_0's binary_logloss: 0.535303
# [251]	valid_0's binary_logloss: 0.53526
# [252]	valid_0's binary_logloss: 0.535247
# [253]	valid_0's binary_logloss: 0.535215
# [254]	valid_0's binary_logloss: 0.535203
# [255]	valid_0's binary_logloss: 0.535142
# [256]	valid_0's binary_logloss: 0.535124
# [257]	valid_0's binary_logloss: 0.535084
# [258]	valid_0's binary_logloss: 0.53505
# [259]	valid_0's binary_logloss: 0.535003
# [260]	valid_0's binary_logloss: 0.534982
# [261]	valid_0's binary_logloss: 0.534955
# [262]	valid_0's binary_logloss: 0.534934
# [263]	valid_0's binary_logloss: 0.534905
# [264]	valid_0's binary_logloss: 0.534873
# [265]	valid_0's binary_logloss: 0.534861
# [266]	valid_0's binary_logloss: 0.534827
# [267]	valid_0's binary_logloss: 0.5348
# [268]	valid_0's binary_logloss: 0.534778
# [269]	valid_0's binary_logloss: 0.534764
# [270]	valid_0's binary_logloss: 0.534747
# [271]	valid_0's binary_logloss: 0.534722
# [272]	valid_0's binary_logloss: 0.534706
# [273]	valid_0's binary_logloss: 0.534672
# [274]	valid_0's binary_logloss: 0.534649
# [275]	valid_0's binary_logloss: 0.534628
# [276]	valid_0's binary_logloss: 0.534597
# [277]	valid_0's binary_logloss: 0.534576
# [278]	valid_0's binary_logloss: 0.534536
# [279]	valid_0's binary_logloss: 0.534516
# [280]	valid_0's binary_logloss: 0.53449
# [281]	valid_0's binary_logloss: 0.534482
# [282]	valid_0's binary_logloss: 0.534458
# [283]	valid_0's binary_logloss: 0.534441
# [284]	valid_0's binary_logloss: 0.534424
# [285]	valid_0's binary_logloss: 0.534411
# [286]	valid_0's binary_logloss: 0.534373
# [287]	valid_0's binary_logloss: 0.534352
# [288]	valid_0's binary_logloss: 0.534332
# [289]	valid_0's binary_logloss: 0.534296
# [290]	valid_0's binary_logloss: 0.534277
# [291]	valid_0's binary_logloss: 0.534252
# [292]	valid_0's binary_logloss: 0.534242
# [293]	valid_0's binary_logloss: 0.534205
# [294]	valid_0's binary_logloss: 0.534189
# [295]	valid_0's binary_logloss: 0.534177
# [296]	valid_0's binary_logloss: 0.534164
# [297]	valid_0's binary_logloss: 0.534129
# [298]	valid_0's binary_logloss: 0.534095
# [299]	valid_0's binary_logloss: 0.534079
# [300]	valid_0's binary_logloss: 0.534004
# [301]	valid_0's binary_logloss: 0.533989
# [302]	valid_0's binary_logloss: 0.53395
# [303]	valid_0's binary_logloss: 0.533928
# [304]	valid_0's binary_logloss: 0.533918
# [305]	valid_0's binary_logloss: 0.5339
# [306]	valid_0's binary_logloss: 0.533885
# [307]	valid_0's binary_logloss: 0.533853
# [308]	valid_0's binary_logloss: 0.533836
# [309]	valid_0's binary_logloss: 0.533814
# [310]	valid_0's binary_logloss: 0.5338
# [311]	valid_0's binary_logloss: 0.533792
# [312]	valid_0's binary_logloss: 0.533781
# [313]	valid_0's binary_logloss: 0.533756
# [314]	valid_0's binary_logloss: 0.533743
# [315]	valid_0's binary_logloss: 0.533729
# [316]	valid_0's binary_logloss: 0.533703
# [317]	valid_0's binary_logloss: 0.533692
# [318]	valid_0's binary_logloss: 0.533682
# [319]	valid_0's binary_logloss: 0.533655
# [320]	valid_0's binary_logloss: 0.533617
# [321]	valid_0's binary_logloss: 0.533595
# [322]	valid_0's binary_logloss: 0.533585
# [323]	valid_0's binary_logloss: 0.533569
# [324]	valid_0's binary_logloss: 0.533564
# [325]	valid_0's binary_logloss: 0.533541
# [326]	valid_0's binary_logloss: 0.533538
# [327]	valid_0's binary_logloss: 0.533528
# [328]	valid_0's binary_logloss: 0.533513
# [329]	valid_0's binary_logloss: 0.533505
# [330]	valid_0's binary_logloss: 0.533494
# [331]	valid_0's binary_logloss: 0.533462
# [332]	valid_0's binary_logloss: 0.533439
# [333]	valid_0's binary_logloss: 0.533401
# [334]	valid_0's binary_logloss: 0.533392
# [335]	valid_0's binary_logloss: 0.533388
# [336]	valid_0's binary_logloss: 0.533374
# [337]	valid_0's binary_logloss: 0.533363
# [338]	valid_0's binary_logloss: 0.533344
# [339]	valid_0's binary_logloss: 0.533329
# [340]	valid_0's binary_logloss: 0.533322
# [341]	valid_0's binary_logloss: 0.533285
# [342]	valid_0's binary_logloss: 0.533261
# [343]	valid_0's binary_logloss: 0.533197
# [344]	valid_0's binary_logloss: 0.533186
# [345]	valid_0's binary_logloss: 0.53316
# [346]	valid_0's binary_logloss: 0.533149
# [347]	valid_0's binary_logloss: 0.533132
# [348]	valid_0's binary_logloss: 0.533095
# [349]	valid_0's binary_logloss: 0.533074
# [350]	valid_0's binary_logloss: 0.533017
# [351]	valid_0's binary_logloss: 0.533006
# [352]	valid_0's binary_logloss: 0.532997
# [353]	valid_0's binary_logloss: 0.532986
# [354]	valid_0's binary_logloss: 0.53297
# [355]	valid_0's binary_logloss: 0.532968
# [356]	valid_0's binary_logloss: 0.532954
# [357]	valid_0's binary_logloss: 0.532942
# [358]	valid_0's binary_logloss: 0.532913
# [359]	valid_0's binary_logloss: 0.532862
# [360]	valid_0's binary_logloss: 0.532832
# [361]	valid_0's binary_logloss: 0.532796
# [362]	valid_0's binary_logloss: 0.532788
# [363]	valid_0's binary_logloss: 0.532778
# [364]	valid_0's binary_logloss: 0.532773
# [365]	valid_0's binary_logloss: 0.532751
# [366]	valid_0's binary_logloss: 0.532749
# [367]	valid_0's binary_logloss: 0.532739
# [368]	valid_0's binary_logloss: 0.532711
# [369]	valid_0's binary_logloss: 0.53269
# [370]	valid_0's binary_logloss: 0.532681
# [371]	valid_0's binary_logloss: 0.532656
# [372]	valid_0's binary_logloss: 0.532644
# [373]	valid_0's binary_logloss: 0.532613
# [374]	valid_0's binary_logloss: 0.532607
# [375]	valid_0's binary_logloss: 0.532602
# [376]	valid_0's binary_logloss: 0.532591
# [377]	valid_0's binary_logloss: 0.532562
# [378]	valid_0's binary_logloss: 0.532554
# [379]	valid_0's binary_logloss: 0.532522
# [380]	valid_0's binary_logloss: 0.532519
# [381]	valid_0's binary_logloss: 0.532513
# [382]	valid_0's binary_logloss: 0.532483
# [383]	valid_0's binary_logloss: 0.532479
# [384]	valid_0's binary_logloss: 0.53247
# [385]	valid_0's binary_logloss: 0.532448
# [386]	valid_0's binary_logloss: 0.53244
# [387]	valid_0's binary_logloss: 0.532419
# [388]	valid_0's binary_logloss: 0.532411
# [389]	valid_0's binary_logloss: 0.532372
# [390]	valid_0's binary_logloss: 0.532365
# [391]	valid_0's binary_logloss: 0.532326
# [392]	valid_0's binary_logloss: 0.532318
# [393]	valid_0's binary_logloss: 0.532297
# [394]	valid_0's binary_logloss: 0.532283
# [395]	valid_0's binary_logloss: 0.532243
# [396]	valid_0's binary_logloss: 0.532237
# [397]	valid_0's binary_logloss: 0.532234
# [398]	valid_0's binary_logloss: 0.53223
# [399]	valid_0's binary_logloss: 0.532223
# [400]	valid_0's binary_logloss: 0.5322
# [401]	valid_0's binary_logloss: 0.532196
# [402]	valid_0's binary_logloss: 0.532186
# [403]	valid_0's binary_logloss: 0.532173
# [404]	valid_0's binary_logloss: 0.53215
# [405]	valid_0's binary_logloss: 0.532124
# [406]	valid_0's binary_logloss: 0.532088
# [407]	valid_0's binary_logloss: 0.532077
# [408]	valid_0's binary_logloss: 0.532053
# [409]	valid_0's binary_logloss: 0.532027
# [410]	valid_0's binary_logloss: 0.532022
# [411]	valid_0's binary_logloss: 0.532008
# [412]	valid_0's binary_logloss: 0.531972
# [413]	valid_0's binary_logloss: 0.531931
# [414]	valid_0's binary_logloss: 0.531924
# [415]	valid_0's binary_logloss: 0.531919
# [416]	valid_0's binary_logloss: 0.531905
# [417]	valid_0's binary_logloss: 0.5319
# [418]	valid_0's binary_logloss: 0.531893
# [419]	valid_0's binary_logloss: 0.531893
# [420]	valid_0's binary_logloss: 0.531886
# [421]	valid_0's binary_logloss: 0.531868
# [422]	valid_0's binary_logloss: 0.531855
# [423]	valid_0's binary_logloss: 0.531818
# [424]	valid_0's binary_logloss: 0.531809
# [425]	valid_0's binary_logloss: 0.531798
# [426]	valid_0's binary_logloss: 0.531796
# [427]	valid_0's binary_logloss: 0.531771
# [428]	valid_0's binary_logloss: 0.531756
# [429]	valid_0's binary_logloss: 0.531753
# [430]	valid_0's binary_logloss: 0.531745
# [431]	valid_0's binary_logloss: 0.531735
# [432]	valid_0's binary_logloss: 0.531727
# [433]	valid_0's binary_logloss: 0.531703
# [434]	valid_0's binary_logloss: 0.531693
# [435]	valid_0's binary_logloss: 0.531671
# [436]	valid_0's binary_logloss: 0.531653
# [437]	valid_0's binary_logloss: 0.531631
# [438]	valid_0's binary_logloss: 0.531615
# [439]	valid_0's binary_logloss: 0.531579
# [440]	valid_0's binary_logloss: 0.531555
# [441]	valid_0's binary_logloss: 0.531551
# [442]	valid_0's binary_logloss: 0.531533
# [443]	valid_0's binary_logloss: 0.531527
# [444]	valid_0's binary_logloss: 0.531522
# [445]	valid_0's binary_logloss: 0.531493
# [446]	valid_0's binary_logloss: 0.531487
# [447]	valid_0's binary_logloss: 0.531476
# [448]	valid_0's binary_logloss: 0.531474
# [449]	valid_0's binary_logloss: 0.531469
# [450]	valid_0's binary_logloss: 0.531428
# [451]	valid_0's binary_logloss: 0.531409
# [452]	valid_0's binary_logloss: 0.531411
# [453]	valid_0's binary_logloss: 0.531404
# [454]	valid_0's binary_logloss: 0.531388
# [455]	valid_0's binary_logloss: 0.531368
# [456]	valid_0's binary_logloss: 0.531343
# [457]	valid_0's binary_logloss: 0.531331
# [458]	valid_0's binary_logloss: 0.531314
# [459]	valid_0's binary_logloss: 0.531301
# [460]	valid_0's binary_logloss: 0.531276
# [461]	valid_0's binary_logloss: 0.531251
# [462]	valid_0's binary_logloss: 0.531231
# [463]	valid_0's binary_logloss: 0.531209
# [464]	valid_0's binary_logloss: 0.531193
# [465]	valid_0's binary_logloss: 0.531187
# [466]	valid_0's binary_logloss: 0.531184
# [467]	valid_0's binary_logloss: 0.531175
# [468]	valid_0's binary_logloss: 0.531172
# [469]	valid_0's binary_logloss: 0.531166
# [470]	valid_0's binary_logloss: 0.531142
# [471]	valid_0's binary_logloss: 0.531141
# [472]	valid_0's binary_logloss: 0.531131
# [473]	valid_0's binary_logloss: 0.531109
# [474]	valid_0's binary_logloss: 0.531088
# [475]	valid_0's binary_logloss: 0.531081
# [476]	valid_0's binary_logloss: 0.531073
# [477]	valid_0's binary_logloss: 0.53106
# [478]	valid_0's binary_logloss: 0.531052
# [479]	valid_0's binary_logloss: 0.531034
# [480]	valid_0's binary_logloss: 0.530992
# [481]	valid_0's binary_logloss: 0.530978
# [482]	valid_0's binary_logloss: 0.530956
# [483]	valid_0's binary_logloss: 0.530918
# [484]	valid_0's binary_logloss: 0.530908
# [485]	valid_0's binary_logloss: 0.530873
# [486]	valid_0's binary_logloss: 0.530866
# [487]	valid_0's binary_logloss: 0.530866
# [488]	valid_0's binary_logloss: 0.530848
# [489]	valid_0's binary_logloss: 0.530845
# [490]	valid_0's binary_logloss: 0.530832
# [491]	valid_0's binary_logloss: 0.530828
# [492]	valid_0's binary_logloss: 0.530819
# [493]	valid_0's binary_logloss: 0.530815
# [494]	valid_0's binary_logloss: 0.530799
# [495]	valid_0's binary_logloss: 0.530783
# [496]	valid_0's binary_logloss: 0.530776
# [497]	valid_0's binary_logloss: 0.53077
# [498]	valid_0's binary_logloss: 0.530767
# [499]	valid_0's binary_logloss: 0.530759
# [500]	valid_0's binary_logloss: 0.530736
# [501]	valid_0's binary_logloss: 0.53073
# [502]	valid_0's binary_logloss: 0.530724
# [503]	valid_0's binary_logloss: 0.530713
# [504]	valid_0's binary_logloss: 0.530705
# [505]	valid_0's binary_logloss: 0.530682
# [506]	valid_0's binary_logloss: 0.53067
# [507]	valid_0's binary_logloss: 0.530662
# [508]	valid_0's binary_logloss: 0.530646
# [509]	valid_0's binary_logloss: 0.530638
# [510]	valid_0's binary_logloss: 0.530629
# [511]	valid_0's binary_logloss: 0.530622
# [512]	valid_0's binary_logloss: 0.530602
# [513]	valid_0's binary_logloss: 0.530558
# [514]	valid_0's binary_logloss: 0.530522
# [515]	valid_0's binary_logloss: 0.530516
# [516]	valid_0's binary_logloss: 0.530497
# [517]	valid_0's binary_logloss: 0.530479
# [518]	valid_0's binary_logloss: 0.530438
# [519]	valid_0's binary_logloss: 0.530434
# [520]	valid_0's binary_logloss: 0.530415
# [521]	valid_0's binary_logloss: 0.530395
# [522]	valid_0's binary_logloss: 0.530377
# [523]	valid_0's binary_logloss: 0.530351
# [524]	valid_0's binary_logloss: 0.530328
# [525]	valid_0's binary_logloss: 0.530327
# [526]	valid_0's binary_logloss: 0.530325
# [527]	valid_0's binary_logloss: 0.530308
# [528]	valid_0's binary_logloss: 0.530304
# [529]	valid_0's binary_logloss: 0.530299
# [530]	valid_0's binary_logloss: 0.530264
# [531]	valid_0's binary_logloss: 0.530239
# [532]	valid_0's binary_logloss: 0.530224
# [533]	valid_0's binary_logloss: 0.530207
# [534]	valid_0's binary_logloss: 0.530198
# [535]	valid_0's binary_logloss: 0.53019
# [536]	valid_0's binary_logloss: 0.530173
# [537]	valid_0's binary_logloss: 0.530169
# [538]	valid_0's binary_logloss: 0.530149
# [539]	valid_0's binary_logloss: 0.530133
# [540]	valid_0's binary_logloss: 0.530132
# [541]	valid_0's binary_logloss: 0.530127
# [542]	valid_0's binary_logloss: 0.530112
# [543]	valid_0's binary_logloss: 0.530104
# [544]	valid_0's binary_logloss: 0.530095
# [545]	valid_0's binary_logloss: 0.530079
# [546]	valid_0's binary_logloss: 0.530076
# [547]	valid_0's binary_logloss: 0.530071
# [548]	valid_0's binary_logloss: 0.530067
# [549]	valid_0's binary_logloss: 0.530054
# [550]	valid_0's binary_logloss: 0.530034
# [551]	valid_0's binary_logloss: 0.530023
# [552]	valid_0's binary_logloss: 0.53002
# [553]	valid_0's binary_logloss: 0.530006
# [554]	valid_0's binary_logloss: 0.529976
# [555]	valid_0's binary_logloss: 0.529962
# [556]	valid_0's binary_logloss: 0.529946
# [557]	valid_0's binary_logloss: 0.529942
# [558]	valid_0's binary_logloss: 0.52993
# [559]	valid_0's binary_logloss: 0.529918
# [560]	valid_0's binary_logloss: 0.529902
# [561]	valid_0's binary_logloss: 0.529879
# [562]	valid_0's binary_logloss: 0.529853
# [563]	valid_0's binary_logloss: 0.529847
# [564]	valid_0's binary_logloss: 0.529845
# [565]	valid_0's binary_logloss: 0.529841
# [566]	valid_0's binary_logloss: 0.529837
# [567]	valid_0's binary_logloss: 0.529836
# [568]	valid_0's binary_logloss: 0.529833
# [569]	valid_0's binary_logloss: 0.529822
# [570]	valid_0's binary_logloss: 0.529808
# [571]	valid_0's binary_logloss: 0.529796
# [572]	valid_0's binary_logloss: 0.529777
# [573]	valid_0's binary_logloss: 0.529774
# [574]	valid_0's binary_logloss: 0.529743
# [575]	valid_0's binary_logloss: 0.529713
# [576]	valid_0's binary_logloss: 0.529708
# [577]	valid_0's binary_logloss: 0.529702
# [578]	valid_0's binary_logloss: 0.529687
# [579]	valid_0's binary_logloss: 0.529684
# [580]	valid_0's binary_logloss: 0.529677
# [581]	valid_0's binary_logloss: 0.529665
# [582]	valid_0's binary_logloss: 0.529662
# [583]	valid_0's binary_logloss: 0.529647
# [584]	valid_0's binary_logloss: 0.529635
# [585]	valid_0's binary_logloss: 0.529632
# [586]	valid_0's binary_logloss: 0.529617
# [587]	valid_0's binary_logloss: 0.529594
# [588]	valid_0's binary_logloss: 0.529589
# [589]	valid_0's binary_logloss: 0.529585
# [590]	valid_0's binary_logloss: 0.52957
# [591]	valid_0's binary_logloss: 0.529562
# [592]	valid_0's binary_logloss: 0.529561
# [593]	valid_0's binary_logloss: 0.529548
# [594]	valid_0's binary_logloss: 0.529545
# [595]	valid_0's binary_logloss: 0.529532
# [596]	valid_0's binary_logloss: 0.529523
# [597]	valid_0's binary_logloss: 0.529522
# [598]	valid_0's binary_logloss: 0.529521
# [599]	valid_0's binary_logloss: 0.529508
# [600]	valid_0's binary_logloss: 0.529499
# [601]	valid_0's binary_logloss: 0.529487
# [602]	valid_0's binary_logloss: 0.529485
# [603]	valid_0's binary_logloss: 0.52946
# [604]	valid_0's binary_logloss: 0.529432
# [605]	valid_0's binary_logloss: 0.529425
# [606]	valid_0's binary_logloss: 0.529426
# [607]	valid_0's binary_logloss: 0.529421
# [608]	valid_0's binary_logloss: 0.529413
# [609]	valid_0's binary_logloss: 0.529407
# [610]	valid_0's binary_logloss: 0.529399
# [611]	valid_0's binary_logloss: 0.529386
# [612]	valid_0's binary_logloss: 0.529383
# [613]	valid_0's binary_logloss: 0.529377
# [614]	valid_0's binary_logloss: 0.529364
# [615]	valid_0's binary_logloss: 0.529359
# [616]	valid_0's binary_logloss: 0.529341
# [617]	valid_0's binary_logloss: 0.52934
# [618]	valid_0's binary_logloss: 0.529338
# [619]	valid_0's binary_logloss: 0.529336
# [620]	valid_0's binary_logloss: 0.529311
# [621]	valid_0's binary_logloss: 0.529297
# [622]	valid_0's binary_logloss: 0.529287
# [623]	valid_0's binary_logloss: 0.529287
# [624]	valid_0's binary_logloss: 0.52928
# [625]	valid_0's binary_logloss: 0.529264
# [626]	valid_0's binary_logloss: 0.529233
# [627]	valid_0's binary_logloss: 0.529223
# [628]	valid_0's binary_logloss: 0.529207
# [629]	valid_0's binary_logloss: 0.529197
# [630]	valid_0's binary_logloss: 0.529191
# [631]	valid_0's binary_logloss: 0.529177
# [632]	valid_0's binary_logloss: 0.529165
# [633]	valid_0's binary_logloss: 0.529157
# [634]	valid_0's binary_logloss: 0.529129
# [635]	valid_0's binary_logloss: 0.529125
# [636]	valid_0's binary_logloss: 0.529115
# [637]	valid_0's binary_logloss: 0.529111
# [638]	valid_0's binary_logloss: 0.529107
# [639]	valid_0's binary_logloss: 0.529104
# [640]	valid_0's binary_logloss: 0.529102
# [641]	valid_0's binary_logloss: 0.529101
# [642]	valid_0's binary_logloss: 0.529074
# [643]	valid_0's binary_logloss: 0.529065
# [644]	valid_0's binary_logloss: 0.52904
# [645]	valid_0's binary_logloss: 0.529028
# [646]	valid_0's binary_logloss: 0.529019
# [647]	valid_0's binary_logloss: 0.529001
# [648]	valid_0's binary_logloss: 0.528987
# [649]	valid_0's binary_logloss: 0.528981
# [650]	valid_0's binary_logloss: 0.528978
# [651]	valid_0's binary_logloss: 0.528977
# [652]	valid_0's binary_logloss: 0.528976
# [653]	valid_0's binary_logloss: 0.528973
# [654]	valid_0's binary_logloss: 0.528932
# [655]	valid_0's binary_logloss: 0.528912
# [656]	valid_0's binary_logloss: 0.52889
# [657]	valid_0's binary_logloss: 0.528882
# [658]	valid_0's binary_logloss: 0.528881
# [659]	valid_0's binary_logloss: 0.528861
# [660]	valid_0's binary_logloss: 0.528863
# [661]	valid_0's binary_logloss: 0.528856
# [662]	valid_0's binary_logloss: 0.528852
# [663]	valid_0's binary_logloss: 0.528846
# [664]	valid_0's binary_logloss: 0.528828
# [665]	valid_0's binary_logloss: 0.528816
# [666]	valid_0's binary_logloss: 0.528814
# [667]	valid_0's binary_logloss: 0.528807
# [668]	valid_0's binary_logloss: 0.528795
# [669]	valid_0's binary_logloss: 0.528794
# [670]	valid_0's binary_logloss: 0.528792
# [671]	valid_0's binary_logloss: 0.528784
# [672]	valid_0's binary_logloss: 0.528774
# [673]	valid_0's binary_logloss: 0.528764
# [674]	valid_0's binary_logloss: 0.528758
# [675]	valid_0's binary_logloss: 0.528753
# [676]	valid_0's binary_logloss: 0.528749
# [677]	valid_0's binary_logloss: 0.528748
# [678]	valid_0's binary_logloss: 0.528745
# [679]	valid_0's binary_logloss: 0.528743
# [680]	valid_0's binary_logloss: 0.52872
# [681]	valid_0's binary_logloss: 0.528714
# [682]	valid_0's binary_logloss: 0.528712
# [683]	valid_0's binary_logloss: 0.528705
# [684]	valid_0's binary_logloss: 0.528691
# [685]	valid_0's binary_logloss: 0.528667
# [686]	valid_0's binary_logloss: 0.528662
# [687]	valid_0's binary_logloss: 0.528634
# [688]	valid_0's binary_logloss: 0.528624
# [689]	valid_0's binary_logloss: 0.528624
# [690]	valid_0's binary_logloss: 0.528626
# [691]	valid_0's binary_logloss: 0.528611
# [692]	valid_0's binary_logloss: 0.5286
# [693]	valid_0's binary_logloss: 0.528585
# [694]	valid_0's binary_logloss: 0.52858
# [695]	valid_0's binary_logloss: 0.528568
# [696]	valid_0's binary_logloss: 0.528562
# [697]	valid_0's binary_logloss: 0.52856
# [698]	valid_0's binary_logloss: 0.528556
# [699]	valid_0's binary_logloss: 0.528543
# [700]	valid_0's binary_logloss: 0.528535
# [701]	valid_0's binary_logloss: 0.528534
# [702]	valid_0's binary_logloss: 0.528532
# [703]	valid_0's binary_logloss: 0.528534
# [704]	valid_0's binary_logloss: 0.52853
# [705]	valid_0's binary_logloss: 0.528516
# [706]	valid_0's binary_logloss: 0.528512
# [707]	valid_0's binary_logloss: 0.528509
# [708]	valid_0's binary_logloss: 0.528503
# [709]	valid_0's binary_logloss: 0.52848
# [710]	valid_0's binary_logloss: 0.528467
# [711]	valid_0's binary_logloss: 0.528446
# [712]	valid_0's binary_logloss: 0.528445
# [713]	valid_0's binary_logloss: 0.528444
# [714]	valid_0's binary_logloss: 0.528431
# [715]	valid_0's binary_logloss: 0.528431
# [716]	valid_0's binary_logloss: 0.528427
# [717]	valid_0's binary_logloss: 0.528421
# [718]	valid_0's binary_logloss: 0.528395
# [719]	valid_0's binary_logloss: 0.528379
# [720]	valid_0's binary_logloss: 0.528365
# [721]	valid_0's binary_logloss: 0.528353
# [722]	valid_0's binary_logloss: 0.528334
# [723]	valid_0's binary_logloss: 0.52832
# [724]	valid_0's binary_logloss: 0.52832
# [725]	valid_0's binary_logloss: 0.528315
# [726]	valid_0's binary_logloss: 0.528315
# [727]	valid_0's binary_logloss: 0.528309
# [728]	valid_0's binary_logloss: 0.5283
# [729]	valid_0's binary_logloss: 0.528299
# [730]	valid_0's binary_logloss: 0.528298
# [731]	valid_0's binary_logloss: 0.528289
# [732]	valid_0's binary_logloss: 0.528289
# [733]	valid_0's binary_logloss: 0.528287
# [734]	valid_0's binary_logloss: 0.528282
# [735]	valid_0's binary_logloss: 0.528265
# [736]	valid_0's binary_logloss: 0.528255
# [737]	valid_0's binary_logloss: 0.528247
# [738]	valid_0's binary_logloss: 0.528229
# [739]	valid_0's binary_logloss: 0.528214
# [740]	valid_0's binary_logloss: 0.528194
# [741]	valid_0's binary_logloss: 0.528177
# [742]	valid_0's binary_logloss: 0.528158
# [743]	valid_0's binary_logloss: 0.528149
# [744]	valid_0's binary_logloss: 0.528135
# [745]	valid_0's binary_logloss: 0.528123
# [746]	valid_0's binary_logloss: 0.528122
# [747]	valid_0's binary_logloss: 0.528109
# [748]	valid_0's binary_logloss: 0.5281
# [749]	valid_0's binary_logloss: 0.528101
# [750]	valid_0's binary_logloss: 0.528101
# [751]	valid_0's binary_logloss: 0.528101
# [752]	valid_0's binary_logloss: 0.528096
# [753]	valid_0's binary_logloss: 0.528097
# [754]	valid_0's binary_logloss: 0.528088
# [755]	valid_0's binary_logloss: 0.528071
# [756]	valid_0's binary_logloss: 0.528065
# [757]	valid_0's binary_logloss: 0.528063
# [758]	valid_0's binary_logloss: 0.528059
# [759]	valid_0's binary_logloss: 0.528056
# [760]	valid_0's binary_logloss: 0.528058
# [761]	valid_0's binary_logloss: 0.528051
# [762]	valid_0's binary_logloss: 0.528036
# [763]	valid_0's binary_logloss: 0.528022
# [764]	valid_0's binary_logloss: 0.528006
# [765]	valid_0's binary_logloss: 0.527995
# [766]	valid_0's binary_logloss: 0.52799
# [767]	valid_0's binary_logloss: 0.52799
# [768]	valid_0's binary_logloss: 0.527988
# [769]	valid_0's binary_logloss: 0.527986
# [770]	valid_0's binary_logloss: 0.52798
# [771]	valid_0's binary_logloss: 0.527964
# [772]	valid_0's binary_logloss: 0.527958
# [773]	valid_0's binary_logloss: 0.527946
# [774]	valid_0's binary_logloss: 0.527929
# [775]	valid_0's binary_logloss: 0.527918
# [776]	valid_0's binary_logloss: 0.527912
# [777]	valid_0's binary_logloss: 0.527897
# [778]	valid_0's binary_logloss: 0.527889
# [779]	valid_0's binary_logloss: 0.527888
# [780]	valid_0's binary_logloss: 0.527888
# [781]	valid_0's binary_logloss: 0.527886
# [782]	valid_0's binary_logloss: 0.527883
# [783]	valid_0's binary_logloss: 0.52786
# [784]	valid_0's binary_logloss: 0.52785
# [785]	valid_0's binary_logloss: 0.527838
# [786]	valid_0's binary_logloss: 0.527811
# [787]	valid_0's binary_logloss: 0.527806
# [788]	valid_0's binary_logloss: 0.52778
# [789]	valid_0's binary_logloss: 0.527772
# [790]	valid_0's binary_logloss: 0.527766
# [791]	valid_0's binary_logloss: 0.527765
# [792]	valid_0's binary_logloss: 0.527753
# [793]	valid_0's binary_logloss: 0.527743
# [794]	valid_0's binary_logloss: 0.52772
# [795]	valid_0's binary_logloss: 0.527718
# [796]	valid_0's binary_logloss: 0.527706
# [797]	valid_0's binary_logloss: 0.527699
# [798]	valid_0's binary_logloss: 0.527694
# [799]	valid_0's binary_logloss: 0.527684
# [800]	valid_0's binary_logloss: 0.527678
# [801]	valid_0's binary_logloss: 0.527678
# [802]	valid_0's binary_logloss: 0.527668
# [803]	valid_0's binary_logloss: 0.527655
# [804]	valid_0's binary_logloss: 0.52764
# [805]	valid_0's binary_logloss: 0.527629
# [806]	valid_0's binary_logloss: 0.527623
# [807]	valid_0's binary_logloss: 0.527611
# [808]	valid_0's binary_logloss: 0.527595
# [809]	valid_0's binary_logloss: 0.527581
# [810]	valid_0's binary_logloss: 0.527579
# [811]	valid_0's binary_logloss: 0.52755
# [812]	valid_0's binary_logloss: 0.527544
# [813]	valid_0's binary_logloss: 0.527541
# [814]	valid_0's binary_logloss: 0.527538
# [815]	valid_0's binary_logloss: 0.527536
# [816]	valid_0's binary_logloss: 0.527528
# [817]	valid_0's binary_logloss: 0.527523
# [818]	valid_0's binary_logloss: 0.527511
# [819]	valid_0's binary_logloss: 0.527507
# [820]	valid_0's binary_logloss: 0.527505
# [821]	valid_0's binary_logloss: 0.527498
# [822]	valid_0's binary_logloss: 0.527485
# [823]	valid_0's binary_logloss: 0.527474
# [824]	valid_0's binary_logloss: 0.527458
# [825]	valid_0's binary_logloss: 0.527448
# [826]	valid_0's binary_logloss: 0.527444
# [827]	valid_0's binary_logloss: 0.527438
# [828]	valid_0's binary_logloss: 0.527431
# [829]	valid_0's binary_logloss: 0.527433
# [830]	valid_0's binary_logloss: 0.527431
# [831]	valid_0's binary_logloss: 0.527418
# [832]	valid_0's binary_logloss: 0.527415
# [833]	valid_0's binary_logloss: 0.527407
# [834]	valid_0's binary_logloss: 0.527393
# [835]	valid_0's binary_logloss: 0.527373
# [836]	valid_0's binary_logloss: 0.527346
# [837]	valid_0's binary_logloss: 0.527344
# [838]	valid_0's binary_logloss: 0.527321
# [839]	valid_0's binary_logloss: 0.527308
# [840]	valid_0's binary_logloss: 0.527304
# [841]	valid_0's binary_logloss: 0.52729
# [842]	valid_0's binary_logloss: 0.527284
# [843]	valid_0's binary_logloss: 0.527281
# [844]	valid_0's binary_logloss: 0.527279
# [845]	valid_0's binary_logloss: 0.527278
# [846]	valid_0's binary_logloss: 0.52725
# [847]	valid_0's binary_logloss: 0.527243
# [848]	valid_0's binary_logloss: 0.52723
# [849]	valid_0's binary_logloss: 0.527205
# [850]	valid_0's binary_logloss: 0.527202
# [851]	valid_0's binary_logloss: 0.527194
# [852]	valid_0's binary_logloss: 0.527179
# [853]	valid_0's binary_logloss: 0.527177
# [854]	valid_0's binary_logloss: 0.527166
# [855]	valid_0's binary_logloss: 0.527163
# [856]	valid_0's binary_logloss: 0.527163
# [857]	valid_0's binary_logloss: 0.527162
# [858]	valid_0's binary_logloss: 0.527158
# [859]	valid_0's binary_logloss: 0.527147
# [860]	valid_0's binary_logloss: 0.527138
# [861]	valid_0's binary_logloss: 0.527138
# [862]	valid_0's binary_logloss: 0.52713
# [863]	valid_0's binary_logloss: 0.527129
# [864]	valid_0's binary_logloss: 0.527124
# [865]	valid_0's binary_logloss: 0.527108
# [866]	valid_0's binary_logloss: 0.527101
# [867]	valid_0's binary_logloss: 0.527095
# [868]	valid_0's binary_logloss: 0.527086
# [869]	valid_0's binary_logloss: 0.527081
# [870]	valid_0's binary_logloss: 0.527079
# [871]	valid_0's binary_logloss: 0.527074
# [872]	valid_0's binary_logloss: 0.527064
# [873]	valid_0's binary_logloss: 0.527056
# [874]	valid_0's binary_logloss: 0.527053
# [875]	valid_0's binary_logloss: 0.52705
# [876]	valid_0's binary_logloss: 0.527046
# [877]	valid_0's binary_logloss: 0.527045
# [878]	valid_0's binary_logloss: 0.527045
# [879]	valid_0's binary_logloss: 0.527045
# [880]	valid_0's binary_logloss: 0.527042
# [881]	valid_0's binary_logloss: 0.527039
# [882]	valid_0's binary_logloss: 0.527026
# [883]	valid_0's binary_logloss: 0.526999
# [884]	valid_0's binary_logloss: 0.52699
# [885]	valid_0's binary_logloss: 0.526987
# [886]	valid_0's binary_logloss: 0.526982
# [887]	valid_0's binary_logloss: 0.52698
# [888]	valid_0's binary_logloss: 0.526974
# [889]	valid_0's binary_logloss: 0.526965
# [890]	valid_0's binary_logloss: 0.526956
# [891]	valid_0's binary_logloss: 0.526947
# [892]	valid_0's binary_logloss: 0.526943
# [893]	valid_0's binary_logloss: 0.526943
# [894]	valid_0's binary_logloss: 0.526938
# [895]	valid_0's binary_logloss: 0.526936
# [896]	valid_0's binary_logloss: 0.526929
# [897]	valid_0's binary_logloss: 0.526921
# [898]	valid_0's binary_logloss: 0.526917
# [899]	valid_0's binary_logloss: 0.526902
# [900]	valid_0's binary_logloss: 0.526899
# [901]	valid_0's binary_logloss: 0.526877
# [902]	valid_0's binary_logloss: 0.52685
# [903]	valid_0's binary_logloss: 0.526824
# [904]	valid_0's binary_logloss: 0.526814
# [905]	valid_0's binary_logloss: 0.526803
# [906]	valid_0's binary_logloss: 0.526793
# [907]	valid_0's binary_logloss: 0.52679
# [908]	valid_0's binary_logloss: 0.526777
# [909]	valid_0's binary_logloss: 0.526776
# [910]	valid_0's binary_logloss: 0.52677
# [911]	valid_0's binary_logloss: 0.526762
# [912]	valid_0's binary_logloss: 0.526754
# [913]	valid_0's binary_logloss: 0.526746
# [914]	valid_0's binary_logloss: 0.526721
# [915]	valid_0's binary_logloss: 0.52669
# [916]	valid_0's binary_logloss: 0.526689
# [917]	valid_0's binary_logloss: 0.526685
# [918]	valid_0's binary_logloss: 0.526682
# [919]	valid_0's binary_logloss: 0.526682
# [920]	valid_0's binary_logloss: 0.526675
# [921]	valid_0's binary_logloss: 0.526674
# [922]	valid_0's binary_logloss: 0.526672
# [923]	valid_0's binary_logloss: 0.52665
# [924]	valid_0's binary_logloss: 0.526645
# [925]	valid_0's binary_logloss: 0.52664
# [926]	valid_0's binary_logloss: 0.526633
# [927]	valid_0's binary_logloss: 0.52663
# [928]	valid_0's binary_logloss: 0.526627
# [929]	valid_0's binary_logloss: 0.52662
# [930]	valid_0's binary_logloss: 0.526615
# [931]	valid_0's binary_logloss: 0.526605
# [932]	valid_0's binary_logloss: 0.526597
# [933]	valid_0's binary_logloss: 0.526596
# [934]	valid_0's binary_logloss: 0.526592
# [935]	valid_0's binary_logloss: 0.526586
# [936]	valid_0's binary_logloss: 0.526579
# [937]	valid_0's binary_logloss: 0.526574
# [938]	valid_0's binary_logloss: 0.526569
# [939]	valid_0's binary_logloss: 0.526566
# [940]	valid_0's binary_logloss: 0.526559
# [941]	valid_0's binary_logloss: 0.526552
# [942]	valid_0's binary_logloss: 0.526551
# [943]	valid_0's binary_logloss: 0.52655
# [944]	valid_0's binary_logloss: 0.526545
# [945]	valid_0's binary_logloss: 0.526541
# [946]	valid_0's binary_logloss: 0.526535
# [947]	valid_0's binary_logloss: 0.526524
# [948]	valid_0's binary_logloss: 0.526522
# [949]	valid_0's binary_logloss: 0.52652
# [950]	valid_0's binary_logloss: 0.526518
# [951]	valid_0's binary_logloss: 0.526517
# [952]	valid_0's binary_logloss: 0.526515
# [953]	valid_0's binary_logloss: 0.526513
# [954]	valid_0's binary_logloss: 0.52651
# [955]	valid_0's binary_logloss: 0.526505
# [956]	valid_0's binary_logloss: 0.526499
# [957]	valid_0's binary_logloss: 0.526491
# [958]	valid_0's binary_logloss: 0.526465
# [959]	valid_0's binary_logloss: 0.526461
# [960]	valid_0's binary_logloss: 0.526454
# [961]	valid_0's binary_logloss: 0.526447
# [962]	valid_0's binary_logloss: 0.526441
# [963]	valid_0's binary_logloss: 0.526429
# [964]	valid_0's binary_logloss: 0.526406
# [965]	valid_0's binary_logloss: 0.526404
# [966]	valid_0's binary_logloss: 0.526387
# [967]	valid_0's binary_logloss: 0.526377
# [968]	valid_0's binary_logloss: 0.526373
# [969]	valid_0's binary_logloss: 0.526369
# [970]	valid_0's binary_logloss: 0.526368
# [971]	valid_0's binary_logloss: 0.526363
# [972]	valid_0's binary_logloss: 0.526364
# [973]	valid_0's binary_logloss: 0.526364
# [974]	valid_0's binary_logloss: 0.526359
# [975]	valid_0's binary_logloss: 0.526356
# [976]	valid_0's binary_logloss: 0.526346
# [977]	valid_0's binary_logloss: 0.526337
# [978]	valid_0's binary_logloss: 0.526329
# [979]	valid_0's binary_logloss: 0.526319
# [980]	valid_0's binary_logloss: 0.526314
# [981]	valid_0's binary_logloss: 0.526311
# [982]	valid_0's binary_logloss: 0.526291
# [983]	valid_0's binary_logloss: 0.526283
# [984]	valid_0's binary_logloss: 0.526279
# [985]	valid_0's binary_logloss: 0.526277
# [986]	valid_0's binary_logloss: 0.526261
# [987]	valid_0's binary_logloss: 0.526258
# [988]	valid_0's binary_logloss: 0.526253
# [989]	valid_0's binary_logloss: 0.526253
# [990]	valid_0's binary_logloss: 0.526252
# [991]	valid_0's binary_logloss: 0.526251
# [992]	valid_0's binary_logloss: 0.52625
# [993]	valid_0's binary_logloss: 0.526251
# [994]	valid_0's binary_logloss: 0.526242
# [995]	valid_0's binary_logloss: 0.52624
# [996]	valid_0's binary_logloss: 0.526241
# [997]	valid_0's binary_logloss: 0.526237
# [998]	valid_0's binary_logloss: 0.526236
# [999]	valid_0's binary_logloss: 0.526223
# [1000]	valid_0's binary_logloss: 0.526222
# [1001]	valid_0's binary_logloss: 0.526202
# [1002]	valid_0's binary_logloss: 0.526181
# [1003]	valid_0's binary_logloss: 0.526173
# [1004]	valid_0's binary_logloss: 0.526163
# [1005]	valid_0's binary_logloss: 0.526157
# [1006]	valid_0's binary_logloss: 0.526153
# [1007]	valid_0's binary_logloss: 0.526142
# [1008]	valid_0's binary_logloss: 0.526128
# [1009]	valid_0's binary_logloss: 0.526122
# [1010]	valid_0's binary_logloss: 0.526123
# [1011]	valid_0's binary_logloss: 0.52612
# [1012]	valid_0's binary_logloss: 0.526118
# [1013]	valid_0's binary_logloss: 0.526116
# [1014]	valid_0's binary_logloss: 0.526108
# [1015]	valid_0's binary_logloss: 0.526101
# [1016]	valid_0's binary_logloss: 0.526096
# [1017]	valid_0's binary_logloss: 0.526081
# [1018]	valid_0's binary_logloss: 0.526075
# [1019]	valid_0's binary_logloss: 0.526072
# [1020]	valid_0's binary_logloss: 0.526064
# [1021]	valid_0's binary_logloss: 0.52606
# [1022]	valid_0's binary_logloss: 0.526061
# [1023]	valid_0's binary_logloss: 0.526055
# [1024]	valid_0's binary_logloss: 0.526041
# [1025]	valid_0's binary_logloss: 0.52602
# [1026]	valid_0's binary_logloss: 0.526005
# [1027]	valid_0's binary_logloss: 0.525997
# [1028]	valid_0's binary_logloss: 0.525988
# [1029]	valid_0's binary_logloss: 0.525984
# [1030]	valid_0's binary_logloss: 0.525979
# [1031]	valid_0's binary_logloss: 0.525974
# [1032]	valid_0's binary_logloss: 0.525972
# [1033]	valid_0's binary_logloss: 0.525957
# [1034]	valid_0's binary_logloss: 0.525951
# [1035]	valid_0's binary_logloss: 0.525935
# [1036]	valid_0's binary_logloss: 0.525933
# [1037]	valid_0's binary_logloss: 0.525932
# [1038]	valid_0's binary_logloss: 0.525925
# [1039]	valid_0's binary_logloss: 0.525917
# [1040]	valid_0's binary_logloss: 0.525908
# [1041]	valid_0's binary_logloss: 0.525895
# [1042]	valid_0's binary_logloss: 0.525892
# [1043]	valid_0's binary_logloss: 0.525876
# [1044]	valid_0's binary_logloss: 0.525867
# [1045]	valid_0's binary_logloss: 0.525865
# [1046]	valid_0's binary_logloss: 0.525864
# [1047]	valid_0's binary_logloss: 0.525858
# [1048]	valid_0's binary_logloss: 0.525845
# [1049]	valid_0's binary_logloss: 0.525832
# [1050]	valid_0's binary_logloss: 0.525825
# [1051]	valid_0's binary_logloss: 0.525824
# [1052]	valid_0's binary_logloss: 0.525813
# [1053]	valid_0's binary_logloss: 0.525793
# [1054]	valid_0's binary_logloss: 0.525782
# [1055]	valid_0's binary_logloss: 0.525779
# [1056]	valid_0's binary_logloss: 0.525773
# [1057]	valid_0's binary_logloss: 0.525766
# [1058]	valid_0's binary_logloss: 0.525764
# [1059]	valid_0's binary_logloss: 0.525757
# [1060]	valid_0's binary_logloss: 0.525756
# [1061]	valid_0's binary_logloss: 0.525754
# [1062]	valid_0's binary_logloss: 0.525744
# [1063]	valid_0's binary_logloss: 0.525735
# [1064]	valid_0's binary_logloss: 0.525725
# [1065]	valid_0's binary_logloss: 0.525718
# [1066]	valid_0's binary_logloss: 0.525719
# [1067]	valid_0's binary_logloss: 0.525715
# [1068]	valid_0's binary_logloss: 0.525704
# [1069]	valid_0's binary_logloss: 0.525693
# [1070]	valid_0's binary_logloss: 0.525685
# [1071]	valid_0's binary_logloss: 0.525673
# [1072]	valid_0's binary_logloss: 0.525665
# [1073]	valid_0's binary_logloss: 0.525665
# [1074]	valid_0's binary_logloss: 0.525655
# [1075]	valid_0's binary_logloss: 0.525654
# [1076]	valid_0's binary_logloss: 0.525651
# [1077]	valid_0's binary_logloss: 0.52565
# [1078]	valid_0's binary_logloss: 0.525644
# [1079]	valid_0's binary_logloss: 0.525642
# [1080]	valid_0's binary_logloss: 0.525638
# [1081]	valid_0's binary_logloss: 0.525636
# [1082]	valid_0's binary_logloss: 0.52562
# [1083]	valid_0's binary_logloss: 0.525615
# [1084]	valid_0's binary_logloss: 0.52561
# [1085]	valid_0's binary_logloss: 0.525604
# [1086]	valid_0's binary_logloss: 0.525601
# [1087]	valid_0's binary_logloss: 0.525599
# [1088]	valid_0's binary_logloss: 0.525582
# [1089]	valid_0's binary_logloss: 0.525581
# [1090]	valid_0's binary_logloss: 0.525579
# [1091]	valid_0's binary_logloss: 0.525577
# [1092]	valid_0's binary_logloss: 0.525559
# [1093]	valid_0's binary_logloss: 0.525557
# [1094]	valid_0's binary_logloss: 0.525557
# [1095]	valid_0's binary_logloss: 0.525555
# [1096]	valid_0's binary_logloss: 0.525545
# [1097]	valid_0's binary_logloss: 0.525537
# [1098]	valid_0's binary_logloss: 0.525532
# [1099]	valid_0's binary_logloss: 0.525529
# [1100]	valid_0's binary_logloss: 0.525527
# [1101]	valid_0's binary_logloss: 0.525518
# [1102]	valid_0's binary_logloss: 0.525515
# [1103]	valid_0's binary_logloss: 0.525515
# [1104]	valid_0's binary_logloss: 0.525512
# [1105]	valid_0's binary_logloss: 0.525511
# [1106]	valid_0's binary_logloss: 0.525509
# [1107]	valid_0's binary_logloss: 0.525504
# [1108]	valid_0's binary_logloss: 0.525503
# [1109]	valid_0's binary_logloss: 0.525504
# [1110]	valid_0's binary_logloss: 0.525503
# [1111]	valid_0's binary_logloss: 0.525498
# [1112]	valid_0's binary_logloss: 0.525497
# [1113]	valid_0's binary_logloss: 0.52549
# [1114]	valid_0's binary_logloss: 0.525479
# [1115]	valid_0's binary_logloss: 0.525474
# [1116]	valid_0's binary_logloss: 0.525471
# [1117]	valid_0's binary_logloss: 0.52547
# [1118]	valid_0's binary_logloss: 0.525465
# [1119]	valid_0's binary_logloss: 0.525463
# [1120]	valid_0's binary_logloss: 0.525454
# [1121]	valid_0's binary_logloss: 0.525452
# [1122]	valid_0's binary_logloss: 0.525437
# [1123]	valid_0's binary_logloss: 0.525427
# [1124]	valid_0's binary_logloss: 0.525424
# [1125]	valid_0's binary_logloss: 0.525418
# [1126]	valid_0's binary_logloss: 0.525417
# [1127]	valid_0's binary_logloss: 0.525415
# [1128]	valid_0's binary_logloss: 0.525414
# [1129]	valid_0's binary_logloss: 0.525404
# [1130]	valid_0's binary_logloss: 0.525403
# [1131]	valid_0's binary_logloss: 0.525403
# [1132]	valid_0's binary_logloss: 0.5254
# [1133]	valid_0's binary_logloss: 0.525399
# [1134]	valid_0's binary_logloss: 0.525395
# [1135]	valid_0's binary_logloss: 0.525392
# [1136]	valid_0's binary_logloss: 0.525389
# [1137]	valid_0's binary_logloss: 0.525383
# [1138]	valid_0's binary_logloss: 0.525376
# [1139]	valid_0's binary_logloss: 0.525373
# [1140]	valid_0's binary_logloss: 0.525373
# [1141]	valid_0's binary_logloss: 0.52537
# [1142]	valid_0's binary_logloss: 0.525368
# [1143]	valid_0's binary_logloss: 0.525365
# [1144]	valid_0's binary_logloss: 0.525363
# [1145]	valid_0's binary_logloss: 0.525359
# [1146]	valid_0's binary_logloss: 0.52534
# [1147]	valid_0's binary_logloss: 0.525336
# [1148]	valid_0's binary_logloss: 0.52533
# [1149]	valid_0's binary_logloss: 0.525322
# [1150]	valid_0's binary_logloss: 0.525315
# [1151]	valid_0's binary_logloss: 0.52531
# [1152]	valid_0's binary_logloss: 0.525307
# [1153]	valid_0's binary_logloss: 0.525306
# [1154]	valid_0's binary_logloss: 0.525305
# [1155]	valid_0's binary_logloss: 0.525301
# [1156]	valid_0's binary_logloss: 0.5253
# [1157]	valid_0's binary_logloss: 0.525299
# [1158]	valid_0's binary_logloss: 0.525299
# [1159]	valid_0's binary_logloss: 0.5253
# [1160]	valid_0's binary_logloss: 0.525299
# [1161]	valid_0's binary_logloss: 0.525293
# [1162]	valid_0's binary_logloss: 0.525291
# [1163]	valid_0's binary_logloss: 0.525291
# [1164]	valid_0's binary_logloss: 0.525289
# [1165]	valid_0's binary_logloss: 0.525281
# [1166]	valid_0's binary_logloss: 0.52527
# [1167]	valid_0's binary_logloss: 0.525271
# [1168]	valid_0's binary_logloss: 0.525268
# [1169]	valid_0's binary_logloss: 0.525257
# [1170]	valid_0's binary_logloss: 0.525237
# ...
# [5787]	valid_0's binary_logloss: 0.517159
# [5788]	valid_0's binary_logloss: 0.517161
# [5789]	valid_0's binary_logloss: 0.517161
# [5790]	valid_0's binary_logloss: 0.517161
# [5791]	valid_0's binary_logloss: 0.517161
# [5792]	valid_0's binary_logloss: 0.517164
# [5793]	valid_0's binary_logloss: 0.517161
# [5794]	valid_0's binary_logloss: 0.517161
# [5795]	valid_0's binary_logloss: 0.517161
# [5796]	valid_0's binary_logloss: 0.517161
# [5797]	valid_0's binary_logloss: 0.51716
# [5798]	valid_0's binary_logloss: 0.517161
# [5799]	valid_0's binary_logloss: 0.517163
# [5800]	valid_0's binary_logloss: 0.517165
# [5801]	valid_0's binary_logloss: 0.517166
# [5802]	valid_0's binary_logloss: 0.517168
# [5803]	valid_0's binary_logloss: 0.517168
# [5804]	valid_0's binary_logloss: 0.517168
# [5805]	valid_0's binary_logloss: 0.517168
# [5806]	valid_0's binary_logloss: 0.517166
# [5807]	valid_0's binary_logloss: 0.517167
# [5808]	valid_0's binary_logloss: 0.517162
# [5809]	valid_0's binary_logloss: 0.517161
# [5810]	valid_0's binary_logloss: 0.517159
# [5811]	valid_0's binary_logloss: 0.517159
# [5812]	valid_0's binary_logloss: 0.517157
# [5813]	valid_0's binary_logloss: 0.517158
# [5814]	valid_0's binary_logloss: 0.517157
# [5815]	valid_0's binary_logloss: 0.517158
# [5816]	valid_0's binary_logloss: 0.517157
# [5817]	valid_0's binary_logloss: 0.517155
# [5818]	valid_0's binary_logloss: 0.517153
# [5819]	valid_0's binary_logloss: 0.517153
# [5820]	valid_0's binary_logloss: 0.517153
# [5821]	valid_0's binary_logloss: 0.517152
# [5822]	valid_0's binary_logloss: 0.517153
# [5823]	valid_0's binary_logloss: 0.517153
# [5824]	valid_0's binary_logloss: 0.517152
# [5825]	valid_0's binary_logloss: 0.517151
# [5826]	valid_0's binary_logloss: 0.517149
# [5827]	valid_0's binary_logloss: 0.517149
# [5828]	valid_0's binary_logloss: 0.517149
# [5829]	valid_0's binary_logloss: 0.517147
# [5830]	valid_0's binary_logloss: 0.517146
# [5831]	valid_0's binary_logloss: 0.517145
# [5832]	valid_0's binary_logloss: 0.517144
# [5833]	valid_0's binary_logloss: 0.517145
# [5834]	valid_0's binary_logloss: 0.517143
# [5835]	valid_0's binary_logloss: 0.517138
# [5836]	valid_0's binary_logloss: 0.517139
# [5837]	valid_0's binary_logloss: 0.517139
# [5838]	valid_0's binary_logloss: 0.517139
# [5839]	valid_0's binary_logloss: 0.517137
# [5840]	valid_0's binary_logloss: 0.517135
# [5841]	valid_0's binary_logloss: 0.517133
# [5842]	valid_0's binary_logloss: 0.517135
# [5843]	valid_0's binary_logloss: 0.517136
# [5844]	valid_0's binary_logloss: 0.517135
# [5845]	valid_0's binary_logloss: 0.517134
# [5846]	valid_0's binary_logloss: 0.517134
# [5847]	valid_0's binary_logloss: 0.517127
# [5848]	valid_0's binary_logloss: 0.517124
# [5849]	valid_0's binary_logloss: 0.517126
# [5850]	valid_0's binary_logloss: 0.517124
# [5851]	valid_0's binary_logloss: 0.517122
# [5852]	valid_0's binary_logloss: 0.517121
# [5853]	valid_0's binary_logloss: 0.517119
# [5854]	valid_0's binary_logloss: 0.517121
# [5855]	valid_0's binary_logloss: 0.51712
# [5856]	valid_0's binary_logloss: 0.517119
# [5857]	valid_0's binary_logloss: 0.517119
# [5858]	valid_0's binary_logloss: 0.517117
# [5859]	valid_0's binary_logloss: 0.517116
# [5860]	valid_0's binary_logloss: 0.517115
# [5861]	valid_0's binary_logloss: 0.517117
# [5862]	valid_0's binary_logloss: 0.517114
# [5863]	valid_0's binary_logloss: 0.517111
# [5864]	valid_0's binary_logloss: 0.517113
# [5865]	valid_0's binary_logloss: 0.517112
# [5866]	valid_0's binary_logloss: 0.517112
# [5867]	valid_0's binary_logloss: 0.51711
# [5868]	valid_0's binary_logloss: 0.517111
# [5869]	valid_0's binary_logloss: 0.517112
# [5870]	valid_0's binary_logloss: 0.517112
# [5871]	valid_0's binary_logloss: 0.517113
# [5872]	valid_0's binary_logloss: 0.517113
# [5873]	valid_0's binary_logloss: 0.517113
# [5874]	valid_0's binary_logloss: 0.517113
# [5875]	valid_0's binary_logloss: 0.517108
# [5876]	valid_0's binary_logloss: 0.517107
# [5877]	valid_0's binary_logloss: 0.517106
# [5878]	valid_0's binary_logloss: 0.517106
# [5879]	valid_0's binary_logloss: 0.517102
# [5880]	valid_0's binary_logloss: 0.517101
# [5881]	valid_0's binary_logloss: 0.517103
# [5882]	valid_0's binary_logloss: 0.517104
# [5883]	valid_0's binary_logloss: 0.517104
# [5884]	valid_0's binary_logloss: 0.517105
# [5885]	valid_0's binary_logloss: 0.517103
# [5886]	valid_0's binary_logloss: 0.517104
# [5887]	valid_0's binary_logloss: 0.517104
# [5888]	valid_0's binary_logloss: 0.517104
# [5889]	valid_0's binary_logloss: 0.517104
# [5890]	valid_0's binary_logloss: 0.517102
# [5891]	valid_0's binary_logloss: 0.517098
# [5892]	valid_0's binary_logloss: 0.517096
# [5893]	valid_0's binary_logloss: 0.517095
# [5894]	valid_0's binary_logloss: 0.517096
# [5895]	valid_0's binary_logloss: 0.517095
# [5896]	valid_0's binary_logloss: 0.517096
# [5897]	valid_0's binary_logloss: 0.517094
# [5898]	valid_0's binary_logloss: 0.517093
# [5899]	valid_0's binary_logloss: 0.517092
# [5900]	valid_0's binary_logloss: 0.517089
# [5901]	valid_0's binary_logloss: 0.517089
# [5902]	valid_0's binary_logloss: 0.517086
# [5903]	valid_0's binary_logloss: 0.517085
# [5904]	valid_0's binary_logloss: 0.517079
# [5905]	valid_0's binary_logloss: 0.517075
# [5906]	valid_0's binary_logloss: 0.517076
# [5907]	valid_0's binary_logloss: 0.517077
# [5908]	valid_0's binary_logloss: 0.517078
# [5909]	valid_0's binary_logloss: 0.517078
# [5910]	valid_0's binary_logloss: 0.517079
# [5911]	valid_0's binary_logloss: 0.517079
# [5912]	valid_0's binary_logloss: 0.517081
# [5913]	valid_0's binary_logloss: 0.517081
# [5914]	valid_0's binary_logloss: 0.517081
# [5915]	valid_0's binary_logloss: 0.51708
# [5916]	valid_0's binary_logloss: 0.517074
# [5917]	valid_0's binary_logloss: 0.517075
# [5918]	valid_0's binary_logloss: 0.517076
# [5919]	valid_0's binary_logloss: 0.517077
# [5920]	valid_0's binary_logloss: 0.51707
# [5921]	valid_0's binary_logloss: 0.51707
# [5922]	valid_0's binary_logloss: 0.51707
# [5923]	valid_0's binary_logloss: 0.517066
# [5924]	valid_0's binary_logloss: 0.517066
# [5925]	valid_0's binary_logloss: 0.517067
# [5926]	valid_0's binary_logloss: 0.517066
# [5927]	valid_0's binary_logloss: 0.517066
# [5928]	valid_0's binary_logloss: 0.517068
# [5929]	valid_0's binary_logloss: 0.517069
# [5930]	valid_0's binary_logloss: 0.517068
# [5931]	valid_0's binary_logloss: 0.517066
# [5932]	valid_0's binary_logloss: 0.517064
# [5933]	valid_0's binary_logloss: 0.517062
# [5934]	valid_0's binary_logloss: 0.517061
# [5935]	valid_0's binary_logloss: 0.51706
# [5936]	valid_0's binary_logloss: 0.517061
# [5937]	valid_0's binary_logloss: 0.517062
# [5938]	valid_0's binary_logloss: 0.51706
# [5939]	valid_0's binary_logloss: 0.517061
# [5940]	valid_0's binary_logloss: 0.51706
# [5941]	valid_0's binary_logloss: 0.517061
# [5942]	valid_0's binary_logloss: 0.517061
# [5943]	valid_0's binary_logloss: 0.517061
# [5944]	valid_0's binary_logloss: 0.517057
# [5945]	valid_0's binary_logloss: 0.517056
# [5946]	valid_0's binary_logloss: 0.517055
# [5947]	valid_0's binary_logloss: 0.517054
# [5948]	valid_0's binary_logloss: 0.517048
# [5949]	valid_0's binary_logloss: 0.517046
# [5950]	valid_0's binary_logloss: 0.517045
# [5951]	valid_0's binary_logloss: 0.517045
# [5952]	valid_0's binary_logloss: 0.517044
# [5953]	valid_0's binary_logloss: 0.517043
# [5954]	valid_0's binary_logloss: 0.517042
# [5955]	valid_0's binary_logloss: 0.517042
# [5956]	valid_0's binary_logloss: 0.517034
# [5957]	valid_0's binary_logloss: 0.517036
# [5958]	valid_0's binary_logloss: 0.517036
# [5959]	valid_0's binary_logloss: 0.517036
# [5960]	valid_0's binary_logloss: 0.517037
# [5961]	valid_0's binary_logloss: 0.517037
# [5962]	valid_0's binary_logloss: 0.517037
# [5963]	valid_0's binary_logloss: 0.517037
# [5964]	valid_0's binary_logloss: 0.517037
# [5965]	valid_0's binary_logloss: 0.517035
# [5966]	valid_0's binary_logloss: 0.517036
# [5967]	valid_0's binary_logloss: 0.517034
# [5968]	valid_0's binary_logloss: 0.517034
# [5969]	valid_0's binary_logloss: 0.517034
# [5970]	valid_0's binary_logloss: 0.51703
# [5971]	valid_0's binary_logloss: 0.51703
# [5972]	valid_0's binary_logloss: 0.51703
# [5973]	valid_0's binary_logloss: 0.517032
# [5974]	valid_0's binary_logloss: 0.517032
# [5975]	valid_0's binary_logloss: 0.517034
# [5976]	valid_0's binary_logloss: 0.517033
# [5977]	valid_0's binary_logloss: 0.517033
# [5978]	valid_0's binary_logloss: 0.517032
# [5979]	valid_0's binary_logloss: 0.517031
# [5980]	valid_0's binary_logloss: 0.517033
# [5981]	valid_0's binary_logloss: 0.517033
# [5982]	valid_0's binary_logloss: 0.517035
# [5983]	valid_0's binary_logloss: 0.517034
# [5984]	valid_0's binary_logloss: 0.517033
# [5985]	valid_0's binary_logloss: 0.517029
# [5986]	valid_0's binary_logloss: 0.517028
# [5987]	valid_0's binary_logloss: 0.517026
# [5988]	valid_0's binary_logloss: 0.517028
# [5989]	valid_0's binary_logloss: 0.517028
# [5990]	valid_0's binary_logloss: 0.517027
# [5991]	valid_0's binary_logloss: 0.517026
# [5992]	valid_0's binary_logloss: 0.517026
# [5993]	valid_0's binary_logloss: 0.517027
# [5994]	valid_0's binary_logloss: 0.517028
# [5995]	valid_0's binary_logloss: 0.517027
# [5996]	valid_0's binary_logloss: 0.517026
# [5997]	valid_0's binary_logloss: 0.517027
# [5998]	valid_0's binary_logloss: 0.517027
# [5999]	valid_0's binary_logloss: 0.517027
# [6000]	valid_0's binary_logloss: 0.517023
# [6001]	valid_0's binary_logloss: 0.517017
# [6002]	valid_0's binary_logloss: 0.517017
# [6003]	valid_0's binary_logloss: 0.517018
# [6004]	valid_0's binary_logloss: 0.517018
# [6005]	valid_0's binary_logloss: 0.517016
# [6006]	valid_0's binary_logloss: 0.517018
# [6007]	valid_0's binary_logloss: 0.517017
# [6008]	valid_0's binary_logloss: 0.517013
# [6009]	valid_0's binary_logloss: 0.517011
# [6010]	valid_0's binary_logloss: 0.517009
# [6011]	valid_0's binary_logloss: 0.51701
# [6012]	valid_0's binary_logloss: 0.517007
# [6013]	valid_0's binary_logloss: 0.517007
# [6014]	valid_0's binary_logloss: 0.517009
# [6015]	valid_0's binary_logloss: 0.517009
# [6016]	valid_0's binary_logloss: 0.517011
# [6017]	valid_0's binary_logloss: 0.51701
# [6018]	valid_0's binary_logloss: 0.517011
# [6019]	valid_0's binary_logloss: 0.517011
# [6020]	valid_0's binary_logloss: 0.517013
# [6021]	valid_0's binary_logloss: 0.517013
# [6022]	valid_0's binary_logloss: 0.51701
# [6023]	valid_0's binary_logloss: 0.517008
# [6024]	valid_0's binary_logloss: 0.517007
# [6025]	valid_0's binary_logloss: 0.517007
# [6026]	valid_0's binary_logloss: 0.517006
# [6027]	valid_0's binary_logloss: 0.517002
# [6028]	valid_0's binary_logloss: 0.517002
# [6029]	valid_0's binary_logloss: 0.517001
# [6030]	valid_0's binary_logloss: 0.516997
# [6031]	valid_0's binary_logloss: 0.516997
# [6032]	valid_0's binary_logloss: 0.516998
# [6033]	valid_0's binary_logloss: 0.516999
# [6034]	valid_0's binary_logloss: 0.516999
# [6035]	valid_0's binary_logloss: 0.516998
# [6036]	valid_0's binary_logloss: 0.516998
# [6037]	valid_0's binary_logloss: 0.516997
# [6038]	valid_0's binary_logloss: 0.516996
# [6039]	valid_0's binary_logloss: 0.516995
# [6040]	valid_0's binary_logloss: 0.516997
# [6041]	valid_0's binary_logloss: 0.516996
# [6042]	valid_0's binary_logloss: 0.516997
# [6043]	valid_0's binary_logloss: 0.516996
# [6044]	valid_0's binary_logloss: 0.516996
# [6045]	valid_0's binary_logloss: 0.516996
# [6046]	valid_0's binary_logloss: 0.516993
# [6047]	valid_0's binary_logloss: 0.516992
# [6048]	valid_0's binary_logloss: 0.516992
# [6049]	valid_0's binary_logloss: 0.516993
# [6050]	valid_0's binary_logloss: 0.516992
# [6051]	valid_0's binary_logloss: 0.516993
# [6052]	valid_0's binary_logloss: 0.516992
# [6053]	valid_0's binary_logloss: 0.516987
# [6054]	valid_0's binary_logloss: 0.516987
# [6055]	valid_0's binary_logloss: 0.516986
# [6056]	valid_0's binary_logloss: 0.516987
# [6057]	valid_0's binary_logloss: 0.516987
# [6058]	valid_0's binary_logloss: 0.516986
# [6059]	valid_0's binary_logloss: 0.516988
# [6060]	valid_0's binary_logloss: 0.516989
# [6061]	valid_0's binary_logloss: 0.516988
# [6062]	valid_0's binary_logloss: 0.516988
# [6063]	valid_0's binary_logloss: 0.516988
# [6064]	valid_0's binary_logloss: 0.516988
# [6065]	valid_0's binary_logloss: 0.51699
# [6066]	valid_0's binary_logloss: 0.516989
# [6067]	valid_0's binary_logloss: 0.516991
# [6068]	valid_0's binary_logloss: 0.516991
# [6069]	valid_0's binary_logloss: 0.516991
# [6070]	valid_0's binary_logloss: 0.51699
# [6071]	valid_0's binary_logloss: 0.51699
# [6072]	valid_0's binary_logloss: 0.516989
# [6073]	valid_0's binary_logloss: 0.516988
# [6074]	valid_0's binary_logloss: 0.516987
# [6075]	valid_0's binary_logloss: 0.516988
# [6076]	valid_0's binary_logloss: 0.516987
# [6077]	valid_0's binary_logloss: 0.516987
# [6078]	valid_0's binary_logloss: 0.516988
# [6079]	valid_0's binary_logloss: 0.516988
# [6080]	valid_0's binary_logloss: 0.516988
# [6081]	valid_0's binary_logloss: 0.516985
# [6082]	valid_0's binary_logloss: 0.516984
# [6083]	valid_0's binary_logloss: 0.516985
# [6084]	valid_0's binary_logloss: 0.516984
# [6085]	valid_0's binary_logloss: 0.516982
# [6086]	valid_0's binary_logloss: 0.516982
# [6087]	valid_0's binary_logloss: 0.516982
# [6088]	valid_0's binary_logloss: 0.516983
# [6089]	valid_0's binary_logloss: 0.516982
# [6090]	valid_0's binary_logloss: 0.516981
# [6091]	valid_0's binary_logloss: 0.51698
# [6092]	valid_0's binary_logloss: 0.516973
# [6093]	valid_0's binary_logloss: 0.516972
# [6094]	valid_0's binary_logloss: 0.516974
# [6095]	valid_0's binary_logloss: 0.516974
# [6096]	valid_0's binary_logloss: 0.516973
# [6097]	valid_0's binary_logloss: 0.516974
# [6098]	valid_0's binary_logloss: 0.516974
# [6099]	valid_0's binary_logloss: 0.516974
# [6100]	valid_0's binary_logloss: 0.516973
# [6101]	valid_0's binary_logloss: 0.516973
# [6102]	valid_0's binary_logloss: 0.516974
# [6103]	valid_0's binary_logloss: 0.516974
# [6104]	valid_0's binary_logloss: 0.516975
# [6105]	valid_0's binary_logloss: 0.516974
# [6106]	valid_0's binary_logloss: 0.516974
# [6107]	valid_0's binary_logloss: 0.516973
# [6108]	valid_0's binary_logloss: 0.516971
# [6109]	valid_0's binary_logloss: 0.51697
# [6110]	valid_0's binary_logloss: 0.516969
# [6111]	valid_0's binary_logloss: 0.516971
# [6112]	valid_0's binary_logloss: 0.516969
# [6113]	valid_0's binary_logloss: 0.516968
# [6114]	valid_0's binary_logloss: 0.516968
# [6115]	valid_0's binary_logloss: 0.516968
# [6116]	valid_0's binary_logloss: 0.516969
# [6117]	valid_0's binary_logloss: 0.51697
# [6118]	valid_0's binary_logloss: 0.516971
# [6119]	valid_0's binary_logloss: 0.516971
# [6120]	valid_0's binary_logloss: 0.516972
# [6121]	valid_0's binary_logloss: 0.516971
# [6122]	valid_0's binary_logloss: 0.51697
# [6123]	valid_0's binary_logloss: 0.516971
# [6124]	valid_0's binary_logloss: 0.516971
# [6125]	valid_0's binary_logloss: 0.516971
# [6126]	valid_0's binary_logloss: 0.516972
# [6127]	valid_0's binary_logloss: 0.516971
# [6128]	valid_0's binary_logloss: 0.51697
# [6129]	valid_0's binary_logloss: 0.51697
# [6130]	valid_0's binary_logloss: 0.51697
# [6131]	valid_0's binary_logloss: 0.516972
# [6132]	valid_0's binary_logloss: 0.516972
# [6133]	valid_0's binary_logloss: 0.516973
# [6134]	valid_0's binary_logloss: 0.516972
# [6135]	valid_0's binary_logloss: 0.516974
# [6136]	valid_0's binary_logloss: 0.516973
# [6137]	valid_0's binary_logloss: 0.516974
# [6138]	valid_0's binary_logloss: 0.516976
# [6139]	valid_0's binary_logloss: 0.516975
# [6140]	valid_0's binary_logloss: 0.516976
# [6141]	valid_0's binary_logloss: 0.516977
# [6142]	valid_0's binary_logloss: 0.516978
# [6143]	valid_0's binary_logloss: 0.516979
# [6144]	valid_0's binary_logloss: 0.516978
# [6145]	valid_0's binary_logloss: 0.516979
# [6146]	valid_0's binary_logloss: 0.51698
# [6147]	valid_0's binary_logloss: 0.51698
# [6148]	valid_0's binary_logloss: 0.516981
# [6149]	valid_0's binary_logloss: 0.516981
# [6150]	valid_0's binary_logloss: 0.51698
# [6151]	valid_0's binary_logloss: 0.516979
# [6152]	valid_0's binary_logloss: 0.516981
# [6153]	valid_0's binary_logloss: 0.516981
# [6154]	valid_0's binary_logloss: 0.516981
# [6155]	valid_0's binary_logloss: 0.516982
# [6156]	valid_0's binary_logloss: 0.516983
# [6157]	valid_0's binary_logloss: 0.51698
# [6158]	valid_0's binary_logloss: 0.516978
# [6159]	valid_0's binary_logloss: 0.516974
# [6160]	valid_0's binary_logloss: 0.516974
# [6161]	valid_0's binary_logloss: 0.516973
# [6162]	valid_0's binary_logloss: 0.51697
# [6163]	valid_0's binary_logloss: 0.516969
# [6164]	valid_0's binary_logloss: 0.516968
# [6165]	valid_0's binary_logloss: 0.516969
# Early stopping, best iteration is:
# [6115]	valid_0's binary_logloss: 0.516968

# %%
# get the predicted values for the validation set
y_pred_lgb = lgb_model.predict(X_valid)

# convert the predicted values to binary (0 or 1) based on a threshold of 0.5
y_pred_lgb_binary = [1 if x >= 0.5 else 0 for x in y_pred_lgb]

# calculate the accuracy of the model
accuracy = sum(y_pred_lgb_binary == y_valid) / len(y_valid)
print("Accuracy:", accuracy)

# show me the correctnees by 2x2 table
from sklearn.metrics import confusion_matrix
confusion_matrix(y_valid, y_pred_lgb_binary)
# Out:
# Accuracy: 0.7349493316234789
# array([[51656, 19999],
#        [18031, 53796]])

# %%
lgb_explainer = shap.TreeExplainer(lgb_model)
lgb_shap_values = lgb_explainer.shap_values(X_valid)

shap.summary_plot(lgb_shap_values, data[features])
# Out:
# LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray

# %%
shap.force_plot(lgb_explainer.expected_value[1], lgb_shap_values[1][0, :], X_valid.iloc[0, :])
# Out:
# <div id='iSCS4LEOB505CQ97XSBST'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.33585154813777923, "outValue": -0.040903167634875615, "link": "identity", "featureNames": ["WEEK_YYYYWWW", "SUBSIDIARY_NAME", "CAPTIVE_CHANNEL_FLAG", "COMPANY_CODE", "DIVISION_NAME", "MODEL_CODE", "PREV_PARTS_NO1", "PREV_PARTS_NO2", "PREV_PARTS_NO3", "PREV_PARTS_NO4", "PREV_PARTS_NO5", "RECEIPT_SYMPTOM", "REPAIR_START_DATE", "REPAIR_END_DATE", "CENTER_CODE", "PREV_CENTER_CODE", "PRODUCT_NAME", "PRODUCT_NAME_DETAIL", "RECLAIM", "WARRANTY_TYPE", "PREV_WARRANTY_TYPE", "SVC_TYPE", "PREV_SVC_TYPE", "PREV_ENGINEER_CODE", "PREV_ENGINEER_SYMPTOM", "PREV_ENGINEER_REPAIR", "PREV_KEY_PARTS1", "PREV_KEY_PARTS2", "PREV_KEY_PARTS3", "PREV_KEY_PARTS4", "PREV_KEY_PARTS5", "PREV_KEY_PARTS_REMARK1", "PREV_KEY_PARTS_REMARK2", "PREV_KEY_PARTS_REMARK3", "PREV_KEY_PARTS_REMARK4", "PREV_KEY_PARTS_REMARK5", "PREV_RECEIPT_SYMPTOM", "PREV_RECEIPT_NUMBER_IDX"], "features": {"0": {"effect": 0.001458507223449938, "value": 36.0}, "1": {"effect": -0.10900960564184844, "value": 0.0}, "2": {"effect": -0.010233132059116773, "value": 1.0}, "3": {"effect": -0.03331662662941898, "value": 0.0}, "4": {"effect": -0.09326811005574577, "value": 0.0}, "5": {"effect": -0.06107515323208584, "value": 305.0}, "11": {"effect": 0.04437338850445465, "value": 3.0}, "12": {"effect": -0.160881354529074, "value": 20230112.0}, "13": {"effect": 0.06734526636118895, "value": 20230112.0}, "14": {"effect": 0.11449071454703336, "value": 330.0}, "15": {"effect": 0.10407353226317707, "value": -1.0}, "16": {"effect": -0.051376148430234594, "value": 0.0}, "17": {"effect": 0.21411131755272164, "value": 11.0}, "18": {"effect": 0.007251206092283009, "value": 0.0}, "19": {"effect": -0.20238359596643082, "value": 0.0}, "20": {"effect": -0.0006091730875063963, "value": 0.0}, "21": {"effect": 0.340830061144251, "value": 2.0}, "22": {"effect": 0.00420116923056466, "value": 0.0}, "23": {"effect": 0.0028541286904134834, "value": -1.0}, "24": {"effect": -0.0020017305553077826, "value": 0.0}, "25": {"effect": 0.000492872924542543, "value": 0.0}, "36": {"effect": 0.004959681664007154, "value": -1.0}, "37": {"effect": -0.5590419317839729, "value": -1.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iSCS4LEOB505CQ97XSBST')
#   );
# </script>

# %%
from pytorch_tabnet.tab_model import TabNetClassifier

tabnet_model = TabNetClassifier()
tabnet_model.fit(X_train.values, y_train.values, eval_set=[(X_valid.values, y_valid.values)], patience=10, max_epochs=20)
# Out:
# Device used : cuda
# epoch 0  | loss: 0.59964 | val_0_auc: 0.70776 |  0:00:22s
# epoch 1  | loss: 0.56511 | val_0_auc: 0.77562 |  0:00:44s
# epoch 2  | loss: 0.56171 | val_0_auc: 0.77718 |  0:01:06s
# epoch 3  | loss: 0.56013 | val_0_auc: 0.77721 |  0:01:30s
# epoch 4  | loss: 0.55948 | val_0_auc: 0.77755 |  0:01:53s
# epoch 5  | loss: 0.55982 | val_0_auc: 0.77571 |  0:02:16s
# epoch 6  | loss: 0.56014 | val_0_auc: 0.77448 |  0:02:39s
# epoch 7  | loss: 0.55926 | val_0_auc: 0.77772 |  0:03:02s
# epoch 8  | loss: 0.55814 | val_0_auc: 0.77801 |  0:03:24s
# epoch 9  | loss: 0.55762 | val_0_auc: 0.77998 |  0:03:45s
# epoch 10 | loss: 0.55768 | val_0_auc: 0.77894 |  0:04:05s
# epoch 11 | loss: 0.55716 | val_0_auc: 0.78053 |  0:04:26s
# epoch 12 | loss: 0.55667 | val_0_auc: 0.78132 |  0:04:47s
# epoch 13 | loss: 0.55626 | val_0_auc: 0.78193 |  0:05:08s
# epoch 14 | loss: 0.55642 | val_0_auc: 0.78208 |  0:05:28s
# epoch 15 | loss: 0.55519 | val_0_auc: 0.78236 |  0:05:49s
# epoch 16 | loss: 0.55419 | val_0_auc: 0.7837  |  0:06:10s
# epoch 17 | loss: 0.55394 | val_0_auc: 0.78325 |  0:06:30s
# epoch 18 | loss: 0.55395 | val_0_auc: 0.78493 |  0:06:51s
# epoch 19 | loss: 0.55277 | val_0_auc: 0.78457 |  0:07:12s
# Stop training because you reached max_epochs = 20 with best_epoch = 18 and best_val_0_auc = 0.78493
# Best weights from best epoch are automatically used!

# %%
def tabnet_predict(data):
    return tabnet_model.predict_proba(data)[:, 1]

# %%
# Explain the model predictions using SHAP
x_valid_sample = X_valid.sample(1000)

tabnet_explainer = shap.Explainer(tabnet_predict, X_train.values)
tabnet_shap_values = tabnet_explainer(x_valid_sample.values)

# Plot the SHAP values
shap.summary_plot(tabnet_shap_values, x_valid_sample, feature_names=X_valid.columns)
# Out:
# Permutation explainer: 1001it [07:17,  2.24it/s]
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
# confusion matrix for tabnet
y_pred = tabnet_model.predict(X_valid.values)
accuracy = sum(y_pred == y_valid) / len(y_valid)
print("Accuracy:", accuracy)
confusion_matrix(y_valid, y_pred)
# Out:
# Accuracy: 0.705398586582289
# array([[47826, 23829],
#        [18441, 53386]])
